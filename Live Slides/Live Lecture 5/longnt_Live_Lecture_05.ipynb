# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/1200px-Pandas_logo.svg.png)

# %% [markdown]
# # <center> LESSON 5: Introduction to PANDAS </center>

# %% [markdown]
# ## 1. INTRODUCTION

# %% [markdown]
# ### 1.1 What is Pandas?

# %% [markdown]
# `Pandas = Panel Data`

# %% [markdown]
# ### 1.2 Installation

# %% [markdown]
# - Cài đặt khi tạo môi trường ảo:
# ```
# conda create -n hanh python=3.7 pandas
# ```
# - Cài đặt sau khi tạo xong môi trường ảo:
# ```
# conda install pandas
# ```
# hoặc
# ```
# pip install pandas
# ```

# %% [markdown]
# ### 1.3 Import

# %%
import pandas as pd

# %% [markdown]
# **Reference**:
# - [Pandas Cheatsheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)
# - [Python for Data Analysis](https://bedford-computing.co.uk/learning/wp-content/uploads/2015/10/Python-for-Data-Analysis.pdf)

# %% [markdown]
# ## 2. BASICS

# %% [markdown]
# ### 2.1 Objects in Pandas

# %% [markdown]
# - **DataFrame**: table, `pd.DataFrame()`
# - **Series**: column, `pd.Series()`

# %% [markdown]
# ![](https://media.geeksforgeeks.org/wp-content/cdn-uploads/creating_dataframe1.png)
# ![](https://analyticssavvy.com/wp-content/uploads/2020/05/series-and-dataframe.png)

# %% [markdown]
# #### 2.1.1 How to create a DataFrame

# %% [markdown]
# 1. Tạo ra 1 DataFrame rỗng

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# 2. Tạo ra 1 DataFrame từ dict

# %%
dict1 = {'name':['Long','Linh','Lan'],
       'age':[11,12,13],
       'school':['TMU','NEU','FTU']}
df1 = pd.DataFrame(dict1,index=[f'no{i}' for i in range(1,4)])
df1
# Out:
#      name  age school
# no1  Long   11    TMU
# no2  Linh   12    NEU
# no3   Lan   13    FTU

# %% [markdown]
# 3. Tạo ra 1 DataFrame từ list của list

# %%
li = [['Long',11,'TMU'],['Linh',14,'HUBT'],['Lan',14,'NEU']]
df2 = pd.DataFrame(li, columns=['name','age','school'])
df2
# Out:
#    name  age school
# 0  Long   11    TMU
# 1  Linh   14   HUBT
# 2   Lan   14    NEU

# %% [markdown]
# 4. Tạo ra 1 DataFrame từ zip

# %%
name = ['Long','Linh','Lan']
age =[11,12,13]
school = ['TMU','NEU','FTU']
list(zip(name,age,school))
df3 = pd.DataFrame(list(zip(name,age,school)),columns=['name','age','school'])
df3
# Out:
#    name  age school
# 0  Long   11    TMU
# 1  Linh   12    NEU
# 2   Lan   13    FTU

# %% [markdown]
# 5. Tạo từ 1 chuỗi numpy

# %%
import numpy as np
df4 = pd.DataFrame(np.linspace(1,16,16, dtype=int).reshape(4,4))
df4
# Out:
#     0   1   2   3
# 0   1   2   3   4
# 1   5   6   7   8
# 2   9  10  11  12
# 3  13  14  15  16

# %% [markdown]
# #### 2.1.2 How to create a Series

# %%
dict2 = pd.Series({'name':['Long','Lin','Lang']})
dict2
# Out:
# name    [Long, Lin, Lang]
# dtype: object

# %%
#take a series from a df
df3['name']
# Out:
# 0    Long
# 1    Linh
# 2     Lan
# Name: name, dtype: object

# %%
df3.age
# Out:
# 0    11
# 1    12
# 2    13
# Name: age, dtype: int64

# %% [markdown]
# ### 2.2 I/O
#
# Link: https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data

# %%
## pd.read_[ten duoi file] : pd.read_csv()
## pd.to_[ten duoi file]: pd.to_csv() --> Tải file về máy

# %%
df0 = pd.read_csv('Ecommerce Purchases')
#df.head(): Đọc các dòng đầu theo số đc truyền vào
#df.tail(): Đọc các dòng cuối theo số đc truyền vào
#df.sample(): Đọc ngẫu nhiên số dòng bất kì
df0.head(5)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# 2       Simpson, Williams and Pham      675957666125       08/19
# 3  Williams, Marshall and Buchanan  6011578504430710       02/24
# 4        Brown, Watson and Andrews  6011456623207998       10/25
#
#    CC Security Code                  CC Provider  \
# 0               900                 JCB 16 digit
# 1               561                   Mastercard
# 2               699                 JCB 16 digit
# 3               384                     Discover
# 4               678  Diners Club / Carte Blanche
#
#                             Email                                     Job  \
# 0               pdunlap@yahoo.com  Scientist, product/process development
# 1              anthony41@reed.com                       Drilling engineer
# 2  amymiller@morales-harrison.com                Customer service manager
# 3     brent16@olson-robinson.info                       Drilling engineer
# 4     christopherwright@gmail.com                             Fine artist
#
#         IP Address Language  Purchase Price
# 0  149.146.147.205       el           98.14
# 1     15.160.41.51       fr           70.73
# 2   132.207.160.22       de            0.95
# 3     30.250.74.19       es           78.04
# 4     24.140.33.94       es           77.82

# %%
iris = pd.read_csv('iris.data', header = None)
iris
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
import seaborn as sns
iris2 = sns.load_dataset('iris')
iris2.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %% [markdown]
# ### 2.3 Indexing

# %% [markdown]
# Chọn tất cả các dòng (slicing):
# - `loc`: location `df.loc[row_label,col_label]`, `series.loc[row_label]`
# - `iloc`: index location `df.iloc[row_index,col_index]`, `series.iloc[row_index]`
#
# Chọn 1 cell:
# - `at`:  `df.at[row_label,col_label]`
# - `iat`: `df.iat[row_index,col_index]`

# %%
import seaborn as sns

tips_df = sns.load_dataset('tips')
tips_df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# In ra 6 dong dau tien tu cot total_bill den sex

# %%
tips_df.loc[2,'tip']
# Out:
# 3.5

# %%
tips_df.iloc[3:5,:6]
# Out:
#    total_bill   tip     sex smoker  day    time
# 3       23.68  3.31    Male     No  Sun  Dinner
# 4       24.59  3.61  Female     No  Sun  Dinner

# %%
tips_df.iloc[3,6]
# Out:
# 2

# %%
tips_df.at[3,'sex']
# Out:
# 'Male'

# %%
tips_df.iat[4,2]
# Out:
# 'Female'

# %%
tips_df.iloc[:5:,:3:]
# Out:
#    total_bill   tip     sex
# 0       16.99  1.01  Female
# 1       10.34  1.66    Male
# 2       21.01  3.50    Male
# 3       23.68  3.31    Male
# 4       24.59  3.61  Female

# %%
tips_df.loc[:5:,:'sex']
# Out:
#    total_bill   tip     sex
# 0       16.99  1.01  Female
# 1       10.34  1.66    Male
# 2       21.01  3.50    Male
# 3       23.68  3.31    Male
# 4       24.59  3.61  Female
# 5       25.29  4.71    Male

# %%
#to_frame: Chuyển thành bảng dataframe trông đẹp hơn
#cách 1:
tips_df['sex'].to_frame()
# Out:
#         sex
# 0    Female
# 1      Male
# 2      Male
# 3      Male
# 4    Female
# ..      ...
# 239    Male
# 240  Female
# 241    Male
# 242    Male
# 243  Female
#
# [244 rows x 1 columns]

# %%
#cách 2:
pd.DataFrame(tips_df['sex'])
# Out:
#         sex
# 0    Female
# 1      Male
# 2      Male
# 3      Male
# 4    Female
# ..      ...
# 239    Male
# 240  Female
# 241    Male
# 242    Male
# 243  Female
#
# [244 rows x 1 columns]

# %%
#cách 3: Cho người lười:
tips_df[['sex']]
# Out:
#         sex
# 0    Female
# 1      Male
# 2      Male
# 3      Male
# 4    Female
# ..      ...
# 239    Male
# 240  Female
# 241    Male
# 242    Male
# 243  Female
#
# [244 rows x 1 columns]

# %%
pd.options.display.max_rows = None
pd.options.display.max_columns = None

# %%
tips_df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ### 2.4 Masking
#
# - `df_name.loc[conditions]`
# - `df_name[conditions]`
# - `df_name.query(conditions)`

# %%
tips_df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# - 1. Lấy ra các khách hàng có giới tính nữ

# %%
tips_df.loc[tips_df['sex']=='Female']
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 7 columns]

# %%
tips_df[tips_df['sex']=='Female']
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 7 columns]

# %%
tips_df.query("sex=='Female'").head(5)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 16       10.33  1.67  Female     No  Sun  Dinner     3

# %% [markdown]
# - 2. Lấy ra các khách hàng có giới tính nữ và có hút thuốc
#
# Conditions:
# - sex = female
# - smoker = yes

# %%
tips_df[(tips_df['sex']=='Female') & (tips_df['smoker']=='Yes')].head(5)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 67        3.07  1.00  Female    Yes  Sat  Dinner     1
# 72       26.86  3.14  Female    Yes  Sat  Dinner     2
# 73       25.28  5.00  Female    Yes  Sat  Dinner     2
# 92        5.75  1.00  Female    Yes  Fri  Dinner     2
# 93       16.32  4.30  Female    Yes  Fri  Dinner     2

# %%
tips_df.query("sex=='Female' & smoker=='Yes'").head(5)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 67        3.07  1.00  Female    Yes  Sat  Dinner     1
# 72       26.86  3.14  Female    Yes  Sat  Dinner     2
# 73       25.28  5.00  Female    Yes  Sat  Dinner     2
# 92        5.75  1.00  Female    Yes  Fri  Dinner     2
# 93       16.32  4.30  Female    Yes  Fri  Dinner     2

# %% [markdown]
# ### Bài tập
# 1. Lọc tất cả các bản ghi có tổng hoá đơn >10
# 2. Lọc tất cả các bản ghi chứa các khách hàng không hút thuốc và dùng suất ăn cho 3 người trở lên
# 3. Lọc tất cả các bản ghi chứa khách hàng là nữ ăn tối vào cuối tuần (t7, CN) và tip cho nhân viên từ 5$ trở lên

# %%
#1.
tips_df[tips_df.total_bill > 10].head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#2.
tips_df[(tips_df['smoker']=='No')&(tips_df['size']>3)].head(5)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 13       18.43  3.00    Male     No  Sun  Dinner     4

# %%
#3.
tips_df[(tips_df['sex']=='Female')&(tips_df['time']=='Dinner')&(tips_df['tip']>=5)&(tips_df['day'].str.startswith("S"))]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 11        35.26  5.00  Female     No  Sun  Dinner     4
# 52        34.81  5.20  Female     No  Sun  Dinner     4
# 73        25.28  5.00  Female    Yes  Sat  Dinner     2
# 155       29.85  5.14  Female     No  Sun  Dinner     5
# 214       28.17  6.50  Female    Yes  Sat  Dinner     3

# %%
tips_df.query("sex=='Female' & time=='Dinner' & tip>=5 & day==['Sat','Sun']")
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 11        35.26  5.00  Female     No  Sun  Dinner     4
# 52        34.81  5.20  Female     No  Sun  Dinner     4
# 73        25.28  5.00  Female    Yes  Sat  Dinner     2
# 155       29.85  5.14  Female     No  Sun  Dinner     5
# 214       28.17  6.50  Female    Yes  Sat  Dinner     3

# %% [markdown]
# ### 2.5 Operations

# %% [markdown]
# #### 2.5.1 Groupby

# %% [markdown]
# ![](https://blog.dask.org/images/split-apply-combine.png)

# %% [markdown]
# - Syntax:`groupby()`

# %%
tips_df.head(3) #tail(), sample()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %% [markdown]
# #### 1. Tính trung bình bill mỗi giới tính ăn tại nhà hàng này

# %%
tips_df.groupby('sex').total_bill.mean()
# Out:
# sex
# Male      20.744076
# Female    18.056897
# Name: total_bill, dtype: float64

# %%
tips_df['total_bill_tip'] = tips_df['total_bill']+tips_df['tip']
tips_df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  total_bill_tip
# 0       16.99  1.01  Female     No  Sun  Dinner     2           18.00
# 1       10.34  1.66    Male     No  Sun  Dinner     3           12.00
# 2       21.01  3.50    Male     No  Sun  Dinner     3           24.51

# %%
tips_df.groupby('sex').total_bill_tip.mean().to_frame()
# Out:
#         total_bill_tip
# sex
# Male         23.833694
# Female       20.890345

# %% [markdown]
# #### 2. Tính số tiền lớn nhất, nhỏ nhất và trung bình số tiền mà khách hàng chi trả theo mỗi giới tính

# %%
tips_df.groupby('day').agg({'total_bill':['max','min','mean'],'tip':['max','min','mean']})
# Out:
#      total_bill                     tip
#             max   min       mean    max   min      mean
# day
# Thur      43.11  7.51  17.682742   6.70  1.25  2.771452
# Fri       40.17  5.75  17.151579   4.73  1.00  2.734737
# Sat       50.81  3.07  20.441379  10.00  1.00  2.993103
# Sun       48.17  7.25  21.410000   6.50  1.01  3.255132

# %%
tips_df.groupby('sex').agg(avg_total_bill_tip=('total_bill','mean'))
# Out:
#         avg_total_bill_tip
# sex
# Male             20.744076
# Female           18.056897

# %% [markdown]
# #### 3. Tính tổng doanh thu của nhà hàng theo thời gian dùng bữa của khách hàng theo tip_df
# #### 4. Tính tổng doanh thu (không gồm tip) của nhà hàng theo thời gian dùng bữa với riêng các khách hàng không hút thuốc vào ngày chủ nhật

# %%
tips_df.groupby('time').total_bill_tip.sum().to_frame()
# Out:
#         total_bill_tip
# time
# Lunch          1352.98
# Dinner         4206.37

# %%
tips_df[(tips_df['smoker']=='No')&(tips_df['day']=='Sun')].groupby('time').agg(revenue=('total_bill','sum'))
# Out:
#         revenue
# time
# Lunch      0.00
# Dinner  1168.88

# %% [markdown]
# #### 2.5.2 Pivot
#
# Tinh trung binh so tien moi gioi tinh tra khi an tai nha hang

# %%
tips_df.pivot_table(values='total_bill_tip',index='sex',aggfunc='mean').plot.bar()
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
# tips_df.pivot_table(values='total_bill_tip', index='sex', aggfunc='mean').plot(kind='bar')
# plt.show()

# %% [markdown]
# #### 2.5.3 Concatenation/Join/Merge

# %% [markdown]
# |Merge methods| SQL Join Name | Meaning| _merge|
# |-|-|-|-|
# |left| LEFT OUTER JOIN|Chỉ sử dụng keys bên trái|left_only|
# |right| RIGHT OUTER JOIN|Chỉ sử dụng keys bên phải|right_only|
# |outer|FULL OUTER JOIN|Sử dụng keys của cả 2 dataframes|both|
# |inner|INNER JOIN|Chỉ sử dụng keys giao nhau của 2 dataframes|both|

# %% [markdown]
# ![](https://lh3.googleusercontent.com/-n76c6dtr5sw/YBO5d-3PzGI/AAAAAAAAAh8/xiT6YIzePLEXArb8uU1f1vgg8JRXYeg8ACLcBGAsYHQ/image.png)

# %%
left = tips_df.head(6)[['total_bill','tip']].reset_index()
right = tips_df.loc[4:8][['tip','sex']].reset_index()

# %%
left
# Out:
#    index  total_bill   tip
# 0      0       16.99  1.01
# 1      1       10.34  1.66
# 2      2       21.01  3.50
# 3      3       23.68  3.31
# 4      4       24.59  3.61
# 5      5       25.29  4.71

# %%
right
# Out:
#    index   tip     sex
# 0      4  3.61  Female
# 1      5  4.71    Male
# 2      6  2.00    Male
# 3      7  3.12    Male
# 4      8  1.96    Male

# %%
left.merge(right, how='left', on=['index','tip'])
# Out:
#    index  total_bill   tip     sex
# 0      0       16.99  1.01     NaN
# 1      1       10.34  1.66     NaN
# 2      2       21.01  3.50     NaN
# 3      3       23.68  3.31     NaN
# 4      4       24.59  3.61  Female
# 5      5       25.29  4.71    Male

# %%
left.merge(right, how='right', on=['index','tip'])
# Out:
#    index  total_bill   tip     sex
# 0      4       24.59  3.61  Female
# 1      5       25.29  4.71    Male
# 2      6         NaN  2.00    Male
# 3      7         NaN  3.12    Male
# 4      8         NaN  1.96    Male

# %%
left.merge(right, how='inner', on=['index','tip'])
# Out:
#    index  total_bill   tip     sex
# 0      4       24.59  3.61  Female
# 1      5       25.29  4.71    Male

# %%
left.merge(right, how='outer', on=['index','tip'])
# Out:
#    index  total_bill   tip     sex
# 0      0       16.99  1.01     NaN
# 1      1       10.34  1.66     NaN
# 2      2       21.01  3.50     NaN
# 3      3       23.68  3.31     NaN
# 4      4       24.59  3.61  Female
# 5      5       25.29  4.71    Male
# 6      6         NaN  2.00    Male
# 7      7         NaN  3.12    Male
# 8      8         NaN  1.96    Male

# %%
tips_df.sample(3)
# Out:
#      total_bill   tip     sex smoker   day    time  size  total_bill_tip
# 132       11.17  1.50  Female     No  Thur   Lunch     2           12.67
# 70        12.02  1.97    Male     No   Sat  Dinner     2           13.99
# 73        25.28  5.00  Female    Yes   Sat  Dinner     2           30.28

# %%
pd.concat([tips_df.head(3), tips_df.tail(3), tips_df.sample(3)]) # tap hop cac dataframe co cung format ma minh muon noi
# Out:
#      total_bill   tip     sex smoker   day    time  size  total_bill_tip
# 0         16.99  1.01  Female     No   Sun  Dinner     2           18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3           12.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3           24.51
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2           24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2           19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2           21.78
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2            6.75
# 5         25.29  4.71    Male     No   Sun  Dinner     4           30.00
# 126        8.52  1.48    Male     No  Thur   Lunch     2           10.00
