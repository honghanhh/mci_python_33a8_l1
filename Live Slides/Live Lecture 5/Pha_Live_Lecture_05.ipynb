# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/1200px-Pandas_logo.svg.png)

# %% [markdown]
# # <center> LESSON 5: Introduction to PANDAS </center>

# %% [markdown]
# ## 1. INTRODUCTION

# %% [markdown]
# ### 1.1 What is Pandas?

# %% [markdown]
# `Pandas = Panel Data`

# %% [markdown]
# ### 1.2 Installation

# %% [markdown]
# - Cài đặt khi tạo môi trường ảo:
# ```
# conda create -n hanh python=3.7 pandas
# ```
# - Cài đặt sau khi tạo xong môi trường ảo:
# ```
# conda install pandas
# ```
# hoặc
# ```
# pip install pandas
# ```

# %% [markdown]
# ### 1.3 Import

# %%
import pandas as pd

# %% [markdown]
# **Reference**:
# - [Pandas Cheatsheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)
# - [Python for Data Analysis](https://bedford-computing.co.uk/learning/wp-content/uploads/2015/10/Python-for-Data-Analysis.pdf)

# %% [markdown]
# ## 2. BASICS

# %% [markdown]
# ### 2.1 Objects in Pandas

# %% [markdown]
# - **DataFrame**: table, `pd.DataFrame()`
# - **Series**: column, `pd.Series()`

# %% [markdown]
# ![](https://media.geeksforgeeks.org/wp-content/cdn-uploads/creating_dataframe1.png)
# ![](https://analyticssavvy.com/wp-content/uploads/2020/05/series-and-dataframe.png)

# %% [markdown]
# #### 2.1.1 How to create a DataFrame

# %% [markdown]
# 1. Tạo ra 1 DataFrame rỗng

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# 2. Tạo ra 1 DataFrame từ dict

# %%
dict1 = {'Name': ['Cuong', 'Mai', 'Pha', 'Nghia'],
         'age':[10, 12, 35, 9],
         'university': ['MIT','Harvar', 'ABC', 'Yale']}
df1 = pd.DataFrame(dict1, index = [f'student {i}' for i in range(1,5)])
df1
# Out:
#             Name  age university
# student 1  Cuong   10        MIT
# student 2    Mai   12     Harvar
# student 3    Pha   35        ABC
# student 4  Nghia    9       Yale

# %% [markdown]
# 3. Tạo ra 1 DataFrame từ list của list

# %%
li = [['Cuong', 10, 'MIT'],['Mai', 12, 'Harvard'], ['Pha', 35, 'ABC'], ['Nghia', 9, 'Yale']]
df2 = pd.DataFrame(li, columns = ['Name','Age', 'University'])
df2
# Out:
#     Name  Age University
# 0  Cuong   10        MIT
# 1    Mai   12    Harvard
# 2    Pha   35        ABC
# 3  Nghia    9       Yale

# %% [markdown]
# 4. Tạo ra 1 DataFrame từ zip

# %%
name = ['Cuong', 'Mai', 'Pha', 'Nghia']
age = [10, 12, 35, 9]
university =['MIT','Harvar', 'ABC', 'Yale']
df3 =pd.DataFrame(list(zip(name, age, university)), columns = ['Name','Age', 'University'])
df3
# Out:
#     Name  Age University
# 0  Cuong   10        MIT
# 1    Mai   12     Harvar
# 2    Pha   35        ABC
# 3  Nghia    9       Yale

# %% [markdown]
# 5. Tạo từ 1 chuỗi numpy

# %%
import numpy as np
df4 = pd.DataFrame(np.linspace(1,16,16).reshape(4,4))
df4
# Out:
#       0     1     2     3
# 0   1.0   2.0   3.0   4.0
# 1   5.0   6.0   7.0   8.0
# 2   9.0  10.0  11.0  12.0
# 3  13.0  14.0  15.0  16.0

# %% [markdown]
# #### 2.1.2 How to create a Series

# %%
type(pd.Series({'name': ['Cuong', 'Nghia', 'Mai']}))
# Out:
# pandas.core.series.Series

# %%
df3
# Out:
#     Name  Age University
# 0  Cuong   10        MIT
# 1    Mai   12     Harvar
# 2    Pha   35        ABC
# 3  Nghia    9       Yale

# %%
df3['Name'] # Sử dụng lấy nhiều cột
# Out:
# 0    Cuong
# 1      Mai
# 2      Pha
# 3    Nghia
# Name: Name, dtype: object

# %%
df3.Name #Chỉ lấy được 1 cột có tên viết liền (ko có space)
# Out:
# 0    Cuong
# 1      Mai
# 2      Pha
# 3    Nghia
# Name: Name, dtype: object

# %%
df3[['Name','Age']]
# Out:
#     Name  Age
# 0  Cuong   10
# 1    Mai   12
# 2    Pha   35
# 3  Nghia    9

# %% [markdown]
# ### 2.2 I/O
#
# Link: https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data

# %% [markdown]
# pd.read_{ten_kieu_file} : pd.read_csv(), pd.read_excel(), pd.read_sql()
# pd.to_{ten_kieu_file}: pd.to_csv(), pd.to_excel()
#
# .csv = comma seperated value
#
# .tsv = tab seperated value
#
# .txt

# %%
df = pd.read_csv('Ecommerce Purchases') #local
df.head(5) #df.tall(5), # df.sample(5)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\r\nAlexisborough, NE ...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\r\nSouth John, TN...  28 rn       PM
# 2                 Unit 0065 Box 5052\r\nDPO AP 27450  94 vE       PM
# 3            7780 Julia Fords\r\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\r\nNew Cynthia, TX...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# 2       Simpson, Williams and Pham      675957666125       08/19
# 3  Williams, Marshall and Buchanan  6011578504430710       02/24
# 4        Brown, Watson and Andrews  6011456623207998       10/25
#
#    CC Security Code                  CC Provider  \
# 0               900                 JCB 16 digit
# 1               561                   Mastercard
# 2               699                 JCB 16 digit
# 3               384                     Discover
# 4               678  Diners Club / Carte Blanche
#
#                             Email                                     Job  \
# 0               pdunlap@yahoo.com  Scientist, product/process development
# 1              anthony41@reed.com                       Drilling engineer
# 2  amymiller@morales-harrison.com                Customer service manager
# 3     brent16@olson-robinson.info                       Drilling engineer
# 4     christopherwright@gmail.com                             Fine artist
#
#         IP Address Language  Purchase Price
# 0  149.146.147.205       el           98.14
# 1     15.160.41.51       fr           70.73
# 2   132.207.160.22       de            0.95
# 3     30.250.74.19       es           78.04
# 4     24.140.33.94       es           77.82

# %%
iris = pd.read_csv('iris.data', header = None)
iris.head(5)
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
iris = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')
iris.head(5)
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
import seaborn as sns
iris2 = sns.load_dataset('iris')
iris2.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.to_csv('sample_iris.csv')

# %% [markdown]
# ### 2.3 Indexing

# %% [markdown]
# Chọn tất cả các dòng (slicing):
# - `loc`: location `df.loc[row_label,col_label]`,`series.loc[row_label]`
# - `iloc`: index location
# `df.iloc[row_index,col_index]`, `series.iloc[row_index]`
#
# Chọn 1 cell:
# - `at`:  `df.at[row_label,col_label]`
# - `iat`: `df.iat[row_index,col_index]`

# %%
import seaborn as sns

tips_df = sns.load_dataset('tips')
tips_df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_df.loc[1, 'total_bill']
# Out:
# 10.34

# %%
tips_df.iloc[1,0]
# Out:
# 10.34

# %%
tips_df.at[1, 'total_bill']
# Out:
# 10.34

# %%
tips_df.iat[1,0] #chi lay 1 diem du lieu
# Out:
# 10.34

# %%
#in ra 6 dong dau tien tu cot totalbill - sex
tips_df.loc[0:4,'total_bill':'sex'] # or tips_df.loc[:4,:'sex']
# Out:
#    total_bill   tip     sex
# 0       16.99  1.01  Female
# 1       10.34  1.66    Male
# 2       21.01  3.50    Male
# 3       23.68  3.31    Male
# 4       24.59  3.61  Female

# %%
tips_df.iloc[:5,:3]
# Out:
#    total_bill   tip     sex
# 0       16.99  1.01  Female
# 1       10.34  1.66    Male
# 2       21.01  3.50    Male
# 3       23.68  3.31    Male
# 4       24.59  3.61  Female

# %%
#đổi series => frame => .to_frame
tips_df['total_bill'].to_frame()
# Out:
#      total_bill
# 0         16.99
# 1         10.34
# 2         21.01
# 3         23.68
# 4         24.59
# ..          ...
# 239       29.03
# 240       27.18
# 241       22.67
# 242       17.82
# 243       18.78
#
# [244 rows x 1 columns]

# %%
pd.DataFrame(tips_df['total_bill'])
# Out:
#      total_bill
# 0         16.99
# 1         10.34
# 2         21.01
# 3         23.68
# 4         24.59
# ..          ...
# 239       29.03
# 240       27.18
# 241       22.67
# 242       17.82
# 243       18.78
#
# [244 rows x 1 columns]

# %%
tips_df[['total_bill']]
# Out:
#      total_bill
# 0         16.99
# 1         10.34
# 2         21.01
# 3         23.68
# 4         24.59
# ..          ...
# 239       29.03
# 240       27.18
# 241       22.67
# 242       17.82
# 243       18.78
#
# [244 rows x 1 columns]

# %%
tips_df.iloc[3:5,:6]
# Out:
#    total_bill   tip     sex smoker  day    time
# 3       23.68  3.31    Male     No  Sun  Dinner
# 4       24.59  3.61  Female     No  Sun  Dinner

# %%
tips_df.loc[3:4,:'time']
# Out:
#    total_bill   tip     sex smoker  day    time
# 3       23.68  3.31    Male     No  Sun  Dinner
# 4       24.59  3.61  Female     No  Sun  Dinner

# %%
#in toan bo hoac yeu cau
pd.options.display.max_rows = None #so luong hang can in
pd.options.display.max_column = None #so luong cot can in

# %%
tips_df.describe()

# %% [markdown]
# ### 2.4 Masking
#
# - df_name.loc[conditions]`
# - df_name[conditions]`
# - df_name.query(conditions)`

# %%
tips_df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Lọc ra các thông tin của những khách hàng là nữa với tips_df

# %%
tips_df.loc[tips_df['sex'] == "Female"].head(3)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 11       35.26  5.00  Female     No  Sun  Dinner     4

# %%
tips_df[tips_df['sex'] == "Female"].head(3)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 11       35.26  5.00  Female     No  Sun  Dinner     4

# %%
tips_df.query("sex == 'Female'").head(3)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 11       35.26  5.00  Female     No  Sun  Dinner     4

# %% [markdown]
# Lọc ra các thông tin của những khách hàng là nữ va hut thuoc với tips_df

# %%
tips_df.query(("sex == 'Female' & smoker == 'Yes'")).head(3)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 67        3.07  1.00  Female    Yes  Sat  Dinner     1
# 72       26.86  3.14  Female    Yes  Sat  Dinner     2
# 73       25.28  5.00  Female    Yes  Sat  Dinner     2

# %%
condition = (tips_df['sex'] == 'Female') & (tips_df['smoker'] == 'Yes')
tips_df.loc[condition].head(3)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 67        3.07  1.00  Female    Yes  Sat  Dinner     1
# 72       26.86  3.14  Female    Yes  Sat  Dinner     2
# 73       25.28  5.00  Female    Yes  Sat  Dinner     2

# %% [markdown]
# Bai tap:
# 1. Lọc tất cả các bản ghi chứa thông tin khách hàng là nam mà có tổng hóa đơn > 10
# 2. Lọc tất cả các bản ghi chứa thông tin khách hàng không hút thuốc và có dùng suất ăn 3 người
# 3. Lọc tất cả các bản ghi chứa thông tin khách hàng là nữa ăn tối tại nhà hàng vào cuối tuần và tip cho nhân viên

# %%
tips_df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#con1 = (tips_df['sex'] == 'Male') & (tips_df['total_bill'] > 10) 
tips_df.loc[(tips_df['sex'] == 'Male') & (tips_df['total_bill'] > 10)].head(3)
# Out:
#    total_bill   tip   sex smoker  day    time  size
# 1       10.34  1.66  Male     No  Sun  Dinner     3
# 2       21.01  3.50  Male     No  Sun  Dinner     3
# 3       23.68  3.31  Male     No  Sun  Dinner     2

# %%
tips_df.query("smoker == 'No' & size > 3").head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 7       26.88  3.12    Male     No  Sun  Dinner     4

# %%
tips_df.query("sex == 'Female' & time == 'Dinner' & tip >= 5 & day == ('Sun','Sat')")
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 11        35.26  5.00  Female     No  Sun  Dinner     4
# 52        34.81  5.20  Female     No  Sun  Dinner     4
# 73        25.28  5.00  Female    Yes  Sat  Dinner     2
# 155       29.85  5.14  Female     No  Sun  Dinner     5
# 214       28.17  6.50  Female    Yes  Sat  Dinner     3

# %%
condition = (tips_df['sex'] == 'Female') & (tips_df['time'] == 'Dinner') & (tips_df['day'].str.startswith("S")) & (tips_df['tip'] >= 5)  

tips_df.loc[condition]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 11        35.26  5.00  Female     No  Sun  Dinner     4
# 52        34.81  5.20  Female     No  Sun  Dinner     4
# 73        25.28  5.00  Female    Yes  Sat  Dinner     2
# 155       29.85  5.14  Female     No  Sun  Dinner     5
# 214       28.17  6.50  Female    Yes  Sat  Dinner     3

# %% [markdown]
# ### 2.5 Operations

# %% [markdown]
# #### 2.5.1 Groupby

# %% [markdown]
# ![](https://blog.dask.org/images/split-apply-combine.png)

# %% [markdown]
# Syntax: `groupby()`

# %%
tips_df.head(3) #tail() , sample()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %% [markdown]
# Tinh trung binh so tien moi gioi tinh phai tra

# %%
tips_df.groupby('sex').total_bill.mean()
# Out:
# sex
# Male      20.744076
# Female    18.056897
# Name: total_bill, dtype: float64

# %%
tips_df['total_bill_tip'] = tips_df['total_bill'] + tips_df['tip']
tips_df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  total_bill_tip
# 0       16.99  1.01  Female     No  Sun  Dinner     2           18.00
# 1       10.34  1.66    Male     No  Sun  Dinner     3           12.00
# 2       21.01  3.50    Male     No  Sun  Dinner     3           24.51

# %%
tips_df.groupby('sex').total_bill_tip.mean()#.to_frame()
# Out:
# sex
# Male      23.833694
# Female    20.890345
# Name: total_bill_tip, dtype: float64

# %%
#So tien lon nhat
#So tien nho nhat
#TB hoa don
#so tien tip 
#theo moi gioi tinh

tips_df.groupby('sex').agg({'total_bill':['max', 'min', 'mean'], 'tip':['max', 'min', 'mean']})#Dictionary dieu kien trong agg {key : [value]}
# Out:
#        total_bill                    tip
#               max   min       mean   max  min      mean
# sex
# Male        50.81  7.25  20.744076  10.0  1.0  3.089618
# Female      44.30  3.07  18.056897   6.5  1.0  2.833448

# %%
tips_df.groupby('sex').agg(mean_total_bill_tip = ('total_bill_tip', 'mean'))
# Out:
#         mean_total_bill_tip
# sex
# Male              23.833694
# Female            20.890345

# %%
tips_df.[condition].groupby('sex').agg(mean_total_bill_tip = ('total_bill_tip', 'mean'))

# %% [markdown]
# 1.Tinh tong doanh thu cua nha hang theo thoi gian (buoi an)
# 2.Tinh tong doanh thu ko tinh tip cua nha hang theo thoi gian voi rieng cac khach hang ko hut thuoc

# %%
tips_df.groupby('time').agg(sum_bill = ('total_bill_tip', 'sum'))
# Out:
#         sum_bill
# time
# Lunch    1352.98
# Dinner   4206.37

# %%
tips_df[(tips_df['smoker'] == 'No') & (tips_df['day'] == 'Sun')].groupby('time').total_bill.sum().to_frame()
# Out:
#         total_bill
# time
# Lunch         0.00
# Dinner     1168.88

# %% [markdown]
# #### 2.5.2 Pivot

# %% [markdown]
# Tinh trung binh so tien moi gioi tinh khi an tai nha hang

# %%
tips_df.pivot_table(values = 'total_bill_tip', index = 'sex', aggfunc = 'mean')
# Out:
#         total_bill_tip
# sex
# Male         23.833694
# Female       20.890345

# %%
import matplotlib.pyplot as plt
tips_df.pivot_table(values = 'total_bill_tip', index = 'sex', aggfunc = 'mean').plot.bar();
plt.show()

# %% [markdown]
# #### 2.5.3 Others

# %% [markdown]
# |Merge methods| SQL Join Name | Meaning| _merge|
# |-|-|-|-|
# |left| LEFT OUTER JOIN|Chỉ sử dụng keys bên trái|left_only|
# |right| RIGHT OUTER JOIN|Chỉ sử dụng keys bên phải|right_only|
# |outer|FULL OUTER JOIN|Sử dụng keys của cả 2 dataframes|both|
# |inner|INNER JOIN|Chỉ sử dụng keys giao nhau của 2 dataframes|both|

# %% [markdown]
# ![](https://lh3.googleusercontent.com/-n76c6dtr5sw/YBO5d-3PzGI/AAAAAAAAAh8/xiT6YIzePLEXArb8uU1f1vgg8JRXYeg8ACLcBGAsYHQ/image.png)

# %%
left = tips_df.head(6)[['total_bill', 'tip']].reset_index()
right = tips_df.loc[4:8][['tip', 'sex']].reset_index()

# %%
left
# Out:
#    index  total_bill   tip
# 0      0       16.99  1.01
# 1      1       10.34  1.66
# 2      2       21.01  3.50
# 3      3       23.68  3.31
# 4      4       24.59  3.61
# 5      5       25.29  4.71

# %%
right
# Out:
#    index   tip     sex
# 0      4  3.61  Female
# 1      5  4.71    Male
# 2      6  2.00    Male
# 3      7  3.12    Male
# 4      8  1.96    Male

# %%
left.merge(right , how ='left', on =  ['index', 'tip'])
# Out:
#    index  total_bill   tip     sex
# 0      0       16.99  1.01     NaN
# 1      1       10.34  1.66     NaN
# 2      2       21.01  3.50     NaN
# 3      3       23.68  3.31     NaN
# 4      4       24.59  3.61  Female
# 5      5       25.29  4.71    Male

# %%
left.merge(right , how ='right', on =  ['index', 'tip'])
# Out:
#    index  total_bill   tip     sex
# 0      4       24.59  3.61  Female
# 1      5       25.29  4.71    Male
# 2      6         NaN  2.00    Male
# 3      7         NaN  3.12    Male
# 4      8         NaN  1.96    Male

# %%
left.merge(right , how ='inner', on =  ['index', 'tip'])
# Out:
#    index  total_bill   tip     sex
# 0      4       24.59  3.61  Female
# 1      5       25.29  4.71    Male

# %%
left.merge(right , how ='outer', on =  ['index', 'tip'])
# Out:
#    index  total_bill   tip     sex
# 0      0       16.99  1.01     NaN
# 1      1       10.34  1.66     NaN
# 2      2       21.01  3.50     NaN
# 3      3       23.68  3.31     NaN
# 4      4       24.59  3.61  Female
# 5      5       25.29  4.71    Male
# 6      6         NaN  2.00    Male
# 7      7         NaN  3.12    Male
# 8      8         NaN  1.96    Male

# %%
right.merge(left , how ='outer', on =  ['index', 'tip'])
# Out:
#    index   tip     sex  total_bill
# 0      4  3.61  Female       24.59
# 1      5  4.71    Male       25.29
# 2      6  2.00    Male         NaN
# 3      7  3.12    Male         NaN
# 4      8  1.96    Male         NaN
# 5      0  1.01     NaN       16.99
# 6      1  1.66     NaN       10.34
# 7      2  3.50     NaN       21.01
# 8      3  3.31     NaN       23.68

# %%
tips_df.head(3) #first
tips_df.tail(3) #last
tips_df.sample(3) #random
# Out:
#      total_bill   tip     sex smoker   day    time  size  total_bill_tip
# 121       13.42  1.68  Female     No  Thur   Lunch     2           15.10
# 22        15.77  2.23  Female     No   Sat  Dinner     2           18.00
# 209       12.76  2.23  Female    Yes   Sat  Dinner     2           14.99

# %%
pd.concat([tips_df.head(3), tips_df.tail(3), tips_df.sample(3)]) #tap hop cac df co cung format ma minh muon noi voi nhau, chua tuple
# Out:
#      total_bill   tip     sex smoker   day    time  size  total_bill_tip
# 0         16.99  1.01  Female     No   Sun  Dinner     2           18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3           12.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3           24.51
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2           24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2           19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2           21.78
# 69        15.01  2.09    Male    Yes   Sat  Dinner     2           17.10
# 200       18.71  4.00    Male    Yes  Thur   Lunch     3           22.71
# 127       14.52  2.00  Female     No  Thur   Lunch     2           16.52

# %%
tips_df.reset_index()
# Out:
#      index  total_bill   tip     sex smoker   day    time  size  \
# 0        0       16.99  1.01  Female     No   Sun  Dinner     2
# 1        1       10.34  1.66    Male     No   Sun  Dinner     3
# 2        2       21.01  3.50    Male     No   Sun  Dinner     3
# 3        3       23.68  3.31    Male     No   Sun  Dinner     2
# 4        4       24.59  3.61  Female     No   Sun  Dinner     4
# ..     ...         ...   ...     ...    ...   ...     ...   ...
# 239    239       29.03  5.92    Male     No   Sat  Dinner     3
# 240    240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242    242       17.82  1.75    Male     No   Sat  Dinner     2
# 243    243       18.78  3.00  Female     No  Thur  Dinner     2
#
#      total_bill_tip
# 0             18.00
# 1             12.00
# 2             24.51
# 3             26.99
# 4             28.20
# ..              ...
# 239           34.95
# 240           29.18
# 241           24.67
# 242           19.57
# 243           21.78
#
# [244 rows x 9 columns]
