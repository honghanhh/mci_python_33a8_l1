# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/1200px-Pandas_logo.svg.png)

# %% [markdown]
# # <center> LESSON 5: Introduction to PANDAS </center>

# %% [markdown]
# ## 1. INTRODUCTION

# %% [markdown]
# ### 1.1 What is Pandas?

# %% [markdown]
# `Pandas = Panel Data`
#
# thư viện mã nguồn mở để hỗ trợ xử lý dữ liệu
#
# useful link:
# github pandas and pandas.pydata.org
#
# hay làm việc với time series và structured data (csv,txt,xlsx,...)

# %% [markdown]
# ### 1.2 Installation

# %% [markdown]
# - Cài đặt khi tạo môi trường ảo:
# ```
# conda create -n hanh python=3.7 pandas
# ```
# - Cài đặt sau khi tạo xong môi trường ảo:
# ```
# conda install pandas
# ```
# hoặc
# ```
# pip install pandas
# ```

# %% [markdown]
# ### 1.3 Import

# %%
import pandas as pd

# %% [markdown]
# **Reference**:
# - [Pandas Cheatsheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)
# - [Python for Data Analysis](https://bedford-computing.co.uk/learning/wp-content/uploads/2015/10/Python-for-Data-Analysis.pdf)

# %% [markdown]
# ## 2. BASICS

# %% [markdown]
# ### 2.1 Objects in Pandas

# %% [markdown]
# - **DataFrame**: table, `pd.DataFrame()`
# - **Series**: column, `pd.Series()`

# %% [markdown]
# ![](https://media.geeksforgeeks.org/wp-content/cdn-uploads/creating_dataframe1.png)
# ![](https://analyticssavvy.com/wp-content/uploads/2020/05/series-and-dataframe.png)

# %% [markdown]
# #### 2.1.1 How to create a DataFrame

# %% [markdown]
# 1. Tạo ra 1 DataFrame rỗng

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# 2. Tạo ra 1 DataFrame từ dict

# %%
dict1 = {'name':['Cuong','Mai','Pha','Nghia'],
         'age':[10,12,35,9],
         'uni':['MIT','UOW','NYU','LCU']}
df1 = pd.DataFrame(dict1)
df1
# Out:
#     name  age  uni
# 0  Cuong   10  MIT
# 1    Mai   12  UOW
# 2    Pha   35  NYU
# 3  Nghia    9  LCU

# %%
dict1 = {'name':['Cuong','Mai','Pha','Nghia'],
         'age':[10,12,35,9],
         'uni':['MIT','UOW','NYU','LCU']}
df1 = pd.DataFrame(dict1,index=['student1','student2','student3','student4'])
df1
# Out:
#            name  age  uni
# student1  Cuong   10  MIT
# student2    Mai   12  UOW
# student3    Pha   35  NYU
# student4  Nghia    9  LCU

# %%
dict1 = {'name':['Cuong','Mai','Pha','Nghia'],
         'age':[10,12,35,9],
         'uni':['MIT','UOW','NYU','LCU']}
df1 = pd.DataFrame(dict1,index=[f'student{i}' for i in range(1,5)]) #f = float or to print value in {i}, alright to forfeit
df1
# Out:
#            name  age  uni
# student1  Cuong   10  MIT
# student2    Mai   12  UOW
# student3    Pha   35  NYU
# student4  Nghia    9  LCU

# %% [markdown]
# 3. Tạo ra 1 DataFrame từ list của list

# %%
li = [['Cuong',10,'MIT'],['Mai',12,'UOW'],['Pha',35,'NYU'],['Nghia',9,'LCU']]
df2 = pd.DataFrame(li)
df2
# Out:
#        0   1    2
# 0  Cuong  10  MIT
# 1    Mai  12  UOW
# 2    Pha  35  NYU
# 3  Nghia   9  LCU

# %%
#list khác dict là k có column name -> phải truyền thêm hàm giá trị column

# %%
li = [['Cuong',10,'MIT'],['Mai',12,'UOW'],['Pha',35,'NYU'],['Nghia',9,'LCU']]
df2 = pd.DataFrame(li, columns = ['name','age','uni'])
df2
# Out:
#     name  age  uni
# 0  Cuong   10  MIT
# 1    Mai   12  UOW
# 2    Pha   35  NYU
# 3  Nghia    9  LCU

# %% [markdown]
# 4. Tạo ra 1 DataFrame từ zip

# %%
name = ['Cuong','Mai','Pha','Nghia']
age = [10,12,35,9]
uni = ['MIT','UOW','NYU','LCU']
#zip để match phần tử theo index trên từng list với nhau
zip(name, age, uni)

# %%
list(zip(name, age, uni))
# Out:
# [('Cuong', 10, 'MIT'),
#  ('Mai', 12, 'UOW'),
#  ('Pha', 35, 'NYU'),
#  ('Nghia', 9, 'LCU')]

# %%
df3 = pd.DataFrame(list(zip(name, age, uni)))
df3
# Out:
#        0   1    2
# 0  Cuong  10  MIT
# 1    Mai  12  UOW
# 2    Pha  35  NYU
# 3  Nghia   9  LCU

# %% [markdown]
# 5. Tạo từ 1 chuỗi numpy

# %%
import numpy as np #install + import + typo
df4 = pd.DataFrame(np.linspace(1,16,16).reshape(4,4))
df4
# Out:
#       0     1     2     3
# 0   1.0   2.0   3.0   4.0
# 1   5.0   6.0   7.0   8.0
# 2   9.0  10.0  11.0  12.0
# 3  13.0  14.0  15.0  16.0

# %% [markdown]
# #### 2.1.2 How to create a Series

# %%
type(pd.Series({'name':['Cuong','Mai','Pha','Nghia']}))
# Out:
# pandas.core.series.Series

# %%
type(df2['name'])
# Out:
# pandas.core.series.Series

# %%
df2.name #ra kết quả = lệnh df2['name']
#C1 có thể lấy nhiều cột mà C2 chỉ lấy 1 cột -> có thể lọc được dữ liệu
#C2 chỉ gọi được khi đã define hàm và hàm được viết liền (vd: có thể điền được hàm df.name nhưng không thể đặt hàm df.Ho va ten
# Out:
# 0    Cuong
# 1      Mai
# 2      Pha
# 3    Nghia
# Name: name, dtype: object

# %% [markdown]
# ### 2.2 I/O
#
# Link: https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data

# %% [markdown]
# 'pd.read_(tên_kiểu_file) -> vd: pd.read_csv(),pd.read_excel(),pd.read_txt(),pd.read_sql()'
#
# 'pd.to_(tên_kiểu_file) -> pd.to_csv(), ...'
#
# .csv = commas separated value
#
# .tsv = tab separated value
#
# .txt =

# %%
df = pd.read_csv('Ecommerce Purchases') #local
df.head(5) 
#df.tail(5): đọc 5 dòng cuối cùng
#df.sample(5): đọc random 5 dòng khác nhau trong dataframe
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\r\nAlexisborough, NE ...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\r\nSouth John, TN...  28 rn       PM
# 2                 Unit 0065 Box 5052\r\nDPO AP 27450  94 vE       PM
# 3            7780 Julia Fords\r\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\r\nNew Cynthia, TX...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
iris = pd.read_csv('iris.data', header=None)
iris
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')
iris.head(5)
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
import seaborn as sns
iris2 = sns.load_dataset('iris')
iris2.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.to_csv('sample_uyenlt_iris.csv')

# %% [markdown]
# ### 2.3 Indexing

# %%
# mask to filter conditions 
# agg (aggregation) to conjoin codes
# concat (concatorate) to

# %% [markdown]
# Chọn tất cả các dòng (slicing):
# - `loc`: location `df.loc[row_label,col_label]`, `series.loc[row_label]`
# - `iloc`: index location `df.iloc[row_index,col_index]`, `series.iloc[row_index]`
#
# Chọn 1 cell: (chỉ lấy dc 1 datapoint)
# - `at`:  `df.at[row_label,col_label]`
# - `iat`: `df.iat[row_index,col_index]`

# %%
import seaborn as sns

tips_df = sns.load_dataset('tips')
tips_df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
tips_df.loc[1,'total_bill']
# Out:
# 10.34

# %%
tips_df.iloc[1,0] # iloc dùng index, không dùng tên columns
# Out:
# 10.34

# %%
tips_df.at[1,'total_bill']
# Out:
# 10.34

# %%
tips_df.iat[1,0]
# Out:
# 10.34

# %% [markdown]
# In ra 6 dòng đầu tiên của dataset từ cột total bills đến sex

# %%
tips_df.loc[0:5,'total_bill':'sex']
# Out:
#    total_bill   tip     sex
# 0       16.99  1.01  Female
# 1       10.34  1.66    Male
# 2       21.01  3.50    Male
# 3       23.68  3.31    Male
# 4       24.59  3.61  Female
# 5       25.29  4.71    Male

# %%
tips_df.iloc[0:6,0:3] # nếu lấy từ 0 thì k cần viết 0 cũng được -> :6,:3 & follow principle: inclusive start, exclusive end
# Out:
#    total_bill   tip     sex
# 0       16.99  1.01  Female
# 1       10.34  1.66    Male
# 2       21.01  3.50    Male
# 3       23.68  3.31    Male
# 4       24.59  3.61  Female
# 5       25.29  4.71    Male

# %%
tips_df['total_bill'].to_frame() #biến series thành dataframe có 1 cột
# Out:
#      total_bill
# 0         16.99
# 1         10.34
# 2         21.01
# 3         23.68
# 4         24.59
# ..          ...
# 239       29.03
# 240       27.18
# 241       22.67
# 242       17.82
# 243       18.78
#
# [244 rows x 1 columns]

# %%
pd.DataFrame(tips_df['total_bill'])
# Out:
#      total_bill
# 0         16.99
# 1         10.34
# 2         21.01
# 3         23.68
# 4         24.59
# ..          ...
# 239       29.03
# 240       27.18
# 241       22.67
# 242       17.82
# 243       18.78
#
# [244 rows x 1 columns]

# %%
tips_df[['total_bill']] # another way to turn into a dataframe
# Out:
#      total_bill
# 0         16.99
# 1         10.34
# 2         21.01
# 3         23.68
# 4         24.59
# ..          ...
# 239       29.03
# 240       27.18
# 241       22.67
# 242       17.82
# 243       18.78
#
# [244 rows x 1 columns]

# %%
tips_df.loc[3:4,'total_bill':'time']
# Out:
#    total_bill   tip     sex smoker  day    time
# 3       23.68  3.31    Male     No  Sun  Dinner
# 4       24.59  3.61  Female     No  Sun  Dinner

# %%
tips_df.iloc[3:5,:6]
# Out:
#    total_bill   tip     sex smoker  day    time
# 3       23.68  3.31    Male     No  Sun  Dinner
# 4       24.59  3.61  Female     No  Sun  Dinner

# %%
pd.options.display.max_rows = None #(nếu k mún thì truyền None để tải all)
pd.options.display.max_columns = None
tips_df.loc[:244,'day':'time']
# Out:
#       day    time
# 0     Sun  Dinner
# 1     Sun  Dinner
# 2     Sun  Dinner
# 3     Sun  Dinner
# 4     Sun  Dinner
# 5     Sun  Dinner
# 6     Sun  Dinner
# 7     Sun  Dinner
# 8     Sun  Dinner
# 9     Sun  Dinner
# 10    Sun  Dinner
# 11    Sun  Dinner
# 12    Sun  Dinner
# 13    Sun  Dinner
# 14    Sun  Dinner
# 15    Sun  Dinner
# 16    Sun  Dinner
# 17    Sun  Dinner
# 18    Sun  Dinner
# 19    Sat  Dinner
# 20    Sat  Dinner
# 21    Sat  Dinner
# 22    Sat  Dinner
# 23    Sat  Dinner
# 24    Sat  Dinner
# 25    Sat  Dinner
# 26    Sat  Dinner
# 27    Sat  Dinner
# 28    Sat  Dinner
# 29    Sat  Dinner
# 30    Sat  Dinner
# 31    Sat  Dinner
# 32    Sat  Dinner
# 33    Sat  Dinner
# 34    Sat  Dinner
# 35    Sat  Dinner
# 36    Sat  Dinner
# 37    Sat  Dinner
# 38    Sat  Dinner
# 39    Sat  Dinner
# 40    Sat  Dinner
# 41    Sun  Dinner
# 42    Sun  Dinner
# 43    Sun  Dinner
# 44    Sun  Dinner
# 45    Sun  Dinner
# 46    Sun  Dinner
# 47    Sun  Dinner
# 48    Sun  Dinner
# ...

# %%
tips_df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ### 2.4 Masking
#
# - 'df_name.loc[condition]' -> condition = business logic
# - 'df_name[condition]'
# - 'df_name.query(condition)'

# %%
tips_df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Lọc ra tất cả các thông tin của những khách hàng là nữ với tips_df

# %%
tips_df.loc[tips_df.sex == 'Female'].head(3) #điền tên cột trong nháy hoặc để luôn tên
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 11       35.26  5.00  Female     No  Sun  Dinner     4

# %%
tips_df[tips_df.sex == 'Female'].head(3)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 11       35.26  5.00  Female     No  Sun  Dinner     4

# %%
tips_df.query("sex == 'Female'").head(3)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 11       35.26  5.00  Female     No  Sun  Dinner     4

# %% [markdown]
# Lọc ra các thông tin của KH là nữ có hút thuốc
#
# Conditions: AND / '&'
# - Sex = Female
# - Smoker = Yes

# %%
condition = (tips_df['sex'] == 'Female') & (tips_df['smoker'] == 'Yes')

tips_df.loc[condition]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1
# 72        26.86  3.14  Female    Yes  Sat  Dinner     2
# 73        25.28  5.00  Female    Yes  Sat  Dinner     2
# 92         5.75  1.00  Female    Yes  Fri  Dinner     2
# 93        16.32  4.30  Female    Yes  Fri  Dinner     2
# ..          ...   ...     ...    ...  ...     ...   ...
# 221       13.42  3.48  Female    Yes  Fri   Lunch     2
# 225       16.27  2.50  Female    Yes  Fri   Lunch     2
# 226       10.09  2.00  Female    Yes  Fri   Lunch     2
# 229       22.12  2.88  Female    Yes  Sat  Dinner     2
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
#
# [33 rows x 7 columns]

# %%
tips_df[condition]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1
# 72        26.86  3.14  Female    Yes  Sat  Dinner     2
# 73        25.28  5.00  Female    Yes  Sat  Dinner     2
# 92         5.75  1.00  Female    Yes  Fri  Dinner     2
# 93        16.32  4.30  Female    Yes  Fri  Dinner     2
# ..          ...   ...     ...    ...  ...     ...   ...
# 221       13.42  3.48  Female    Yes  Fri   Lunch     2
# 225       16.27  2.50  Female    Yes  Fri   Lunch     2
# 226       10.09  2.00  Female    Yes  Fri   Lunch     2
# 229       22.12  2.88  Female    Yes  Sat  Dinner     2
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
#
# [33 rows x 7 columns]

# %%
tips_df.query("sex == 'Female' & smoker == 'Yes'")
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1
# 72        26.86  3.14  Female    Yes  Sat  Dinner     2
# 73        25.28  5.00  Female    Yes  Sat  Dinner     2
# 92         5.75  1.00  Female    Yes  Fri  Dinner     2
# 93        16.32  4.30  Female    Yes  Fri  Dinner     2
# ..          ...   ...     ...    ...  ...     ...   ...
# 221       13.42  3.48  Female    Yes  Fri   Lunch     2
# 225       16.27  2.50  Female    Yes  Fri   Lunch     2
# 226       10.09  2.00  Female    Yes  Fri   Lunch     2
# 229       22.12  2.88  Female    Yes  Sat  Dinner     2
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
#
# [33 rows x 7 columns]

# %% [markdown]
# BT:
# 1. Lọc tất cả KH nam mà có tổng hóa đơn >10 (total bill)
# 2. Lọc tất cả KH không hút thuốc và dùng suất ăn (size>=3)
# 3. Lọc tất cả KH nữ ăn tối tại nhà hàng vào cuối tuần (Sat&Sun) và tips cho nhân viên >=5 đô

# %%
condition = (tips_df['sex'] == 'Male') & (tips_df['total_bill'] > 10)

tips_df.loc[condition]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 7         26.88  3.12  Male     No  Sun  Dinner     4
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [146 rows x 7 columns]

# %%
condition = (tips_df['smoker'] == 'No') & (tips_df['size'] >= 3)

tips_df.loc[condition]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# 5         25.29  4.71    Male     No  Sun  Dinner     4
# 7         26.88  3.12    Male     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 212       48.33  9.00    Male     No  Sat  Dinner     4
# 223       15.98  3.00  Female     No  Fri   Lunch     3
# 227       20.45  3.00    Male     No  Sat  Dinner     4
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
#
# [59 rows x 7 columns]

# %%
condition = (tips_df['sex'] == 'Female') & (tips_df['time'] == 'Dinner') & (tips_df['day'].str.startswith("S")) & (tips_df['tip'] >= 5)  

tips_df.loc[condition]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 11        35.26  5.00  Female     No  Sun  Dinner     4
# 52        34.81  5.20  Female     No  Sun  Dinner     4
# 73        25.28  5.00  Female    Yes  Sat  Dinner     2
# 155       29.85  5.14  Female     No  Sun  Dinner     5
# 214       28.17  6.50  Female    Yes  Sat  Dinner     3

# %%
tips_df.query("smoker=='No' & size >=3").head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_df.query("sex=='Female'& day==('Sun','Sat') & tip>=5 & time == 'Dinner'")
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 11        35.26  5.00  Female     No  Sun  Dinner     4
# 52        34.81  5.20  Female     No  Sun  Dinner     4
# 73        25.28  5.00  Female    Yes  Sat  Dinner     2
# 155       29.85  5.14  Female     No  Sun  Dinner     5
# 214       28.17  6.50  Female    Yes  Sat  Dinner     3

# %% [markdown]
# ### 2.5 Operations- Aggregation

# %% [markdown]
# #### 2.5.1 Groupby
# - Để chia dữ liệu thành các bước riêng biệt
# - Sau đó tính toán theo logic của coder hoặc chuyển đổi/lấp đầy các dữ liệu thiếu
# - Rồi combine lại tổng hợp lại thành conclusion - cấu trúc dữ liệu mới - dataframe mới

# %% [markdown]
# ![](https://blog.dask.org/images/split-apply-combine.png)

# %% [markdown]
# - Syntax 'groupby()'

# %%
tips_df.head(3) #tail() or sample()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %% [markdown]
# Tính trung bình số tiền mỗi giới tính phải trả khi ăn tại nhà hàng này

# %%
tips_df.groupby('sex').total_bill.mean()
# Out:
# sex
# Male      20.744076
# Female    18.056897
# Name: total_bill, dtype: float64

# %%
tips_df['total_bill_tip'] = tips_df['total_bill'] + tips_df['tip']
tips_df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  tota_bill_tip  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2          18.00
# 1       10.34  1.66    Male     No  Sun  Dinner     3          12.00
# 2       21.01  3.50    Male     No  Sun  Dinner     3          24.51
#
#    total_bill_tip
# 0           18.00
# 1           12.00
# 2           24.51

# %%
tips_df.groupby('sex').total_bill_tip.mean().to_frame()
# Out:
#         total_bill_tip
# sex
# Male         23.833694
# Female       20.890345

# %% [markdown]
# Số tiền lớn nhất, nhỏ nhất và trung bình hóa đơn và số tiền tips theo giới tính

# %%
tips_df.groupby('sex').agg({'total_bill': ['max','min','mean'],'tip': ['max','min','mean']}) # within agg need to input a dict
# Out:
#        total_bill                    tip
#               max   min       mean   max  min      mean
# sex
# Male        50.81  7.25  20.744076  10.0  1.0  3.089618
# Female      44.30  3.07  18.056897   6.5  1.0  2.833448

# %%
tips_df.groupby('sex').agg(mean_total_bill_tip=('total_bill_tip','mean'), mean_total_bill=('total_bill','mean'))
# Out:
#         mean_total_bill_tip  mean_total_bill
# sex
# Male              23.833694        20.744076
# Female            20.890345        18.056897

# %% [markdown]
# 1. Tính tổng doanh thu của nhà hàng theo thời gian dùng bữa của KH 'tips_df'
# 2. Tính doanh thu (không tính tip) của nhà hàng theo thời gian dùng bữa với riêng các KH không hút thuốc vào ngày chủ nhật

# %%
tips_df.groupby('time').agg(sum_total_bill_tip=('total_bill_tip','sum'), sum_total_bill=('total_bill','sum'))
# Out:
#         sum_total_bill_tip  sum_total_bill
# time
# Lunch              1352.98         1167.47
# Dinner             4206.37         3660.30

# %%
tips_df.groupby('time').total_bill.sum().to_frame()
# Out:
#         total_bill
# time
# Lunch      1167.47
# Dinner     3660.30

# %%
tips_df[(tips_df['smoker'] == 'No') & (tips_df['day']== 'Sun')].groupby('time').total_bill.sum().to_frame()
# Out:
#         total_bill
# time
# Lunch         0.00
# Dinner     1168.88

# %%
tips_df.query("smoker=='No' & day=='Sun'").groupby('time').agg(sum_total_bill=('total_bill','sum'))
# Out:
#         sum_total_bill
# time
# Lunch             0.00
# Dinner         1168.88

# %% [markdown]
# #### 2.5.2 Pivot

# %% [markdown]
# Tính trung bình số tiền mỗi giới tính trả

# %%
tips_df.pivot_table(values='total_bill_tip', index='sex', aggfunc='mean')
# Out:
#         total_bill_tip
# sex
# Male         23.833694
# Female       20.890345

# %%
tips_df.pivot_table(values='total_bill_tip', index='sex', aggfunc='mean').plot.bar()
#nếu không hiện lên được chart thì import matplotlib.pyplot as plt trước rồi sau câu tips_df viết thêm plt.show() để hiển thị
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
tips_df.pivot_table(values='total_bill_tip', index='sex', aggfunc='mean').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %% [markdown]
# #### 2.5.3 Concatenation/Join/Merge

# %% [markdown]
# |Merge methods| SQL Join Name | Meaning| _merge|
# |-|-|-|-|
# |left| LEFT OUTER JOIN|Chỉ sử dụng keys bên trái|left_only|
# |right| RIGHT OUTER JOIN|Chỉ sử dụng keys bên phải|right_only|
# |outer|FULL OUTER JOIN|Sử dụng keys của cả 2 dataframes|both|
# |inner|INNER JOIN|Chỉ sử dụng keys giao nhau của 2 dataframes|both|

# %% [markdown]
# ![](https://lh3.googleusercontent.com/-n76c6dtr5sw/YBO5d-3PzGI/AAAAAAAAAh8/xiT6YIzePLEXArb8uU1f1vgg8JRXYeg8ACLcBGAsYHQ/image.png)

# %%
left = tips_df.head(6)[['total_bill','tip']].reset_index()
right = tips_df.loc[4:8] [['sex','tip']].reset_index()

# %%
left
# Out:
#    index  total_bill   tip
# 0      0       16.99  1.01
# 1      1       10.34  1.66
# 2      2       21.01  3.50
# 3      3       23.68  3.31
# 4      4       24.59  3.61
# 5      5       25.29  4.71

# %%
right
# Out:
#    index     sex   tip
# 0      4  Female  3.61
# 1      5    Male  4.71
# 2      6    Male  2.00
# 3      7    Male  3.12
# 4      8    Male  1.96

# %%
left.merge(right, how='left', on=['index','tip'])
# Out:
#    index  total_bill   tip     sex
# 0      0       16.99  1.01     NaN
# 1      1       10.34  1.66     NaN
# 2      2       21.01  3.50     NaN
# 3      3       23.68  3.31     NaN
# 4      4       24.59  3.61  Female
# 5      5       25.29  4.71    Male

# %%
left.merge(right, how='right', on=['index','tip'])
# Out:
#    index  total_bill   tip     sex
# 0      4       24.59  3.61  Female
# 1      5       25.29  4.71    Male
# 2      6         NaN  2.00    Male
# 3      7         NaN  3.12    Male
# 4      8         NaN  1.96    Male

# %%
left.merge(right, how='inner', on=['index','tip'])
# Out:
#    index  total_bill   tip     sex
# 0      4       24.59  3.61  Female
# 1      5       25.29  4.71    Male

# %%
left.merge(right, how='outer', on=['index','tip'])
# Out:
#    index  total_bill   tip     sex
# 0      0       16.99  1.01     NaN
# 1      1       10.34  1.66     NaN
# 2      2       21.01  3.50     NaN
# 3      3       23.68  3.31     NaN
# 4      4       24.59  3.61  Female
# 5      5       25.29  4.71    Male
# 6      6         NaN  2.00    Male
# 7      7         NaN  3.12    Male
# 8      8         NaN  1.96    Male

# %%
tips_df.tail(3)
# Out:
#      total_bill   tip     sex smoker   day    time  size  tota_bill_tip  \
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2          24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2          19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2          21.78
#
#      total_bill_tip
# 241           24.67
# 242           19.57
# 243           21.78

# %%
tips_df.sample(3)
# Out:
#      total_bill   tip     sex smoker  day    time  size  tota_bill_tip  \
# 53         9.94  1.56    Male     No  Sun  Dinner     2          11.50
# 115       17.31  3.50  Female     No  Sun  Dinner     2          20.81
# 225       16.27  2.50  Female    Yes  Fri   Lunch     2          18.77
#
#      total_bill_tip
# 53            11.50
# 115           20.81
# 225           18.77

# %%
pd.concat([tips_df.head(3), tips_df.tail(3), tips_df.sample(3)]) # cái truyền vào concat là tập hợp các dataframe có cùng format mà mình muốn nối
# Out:
#      total_bill   tip     sex smoker   day    time  size  tota_bill_tip  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2          18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3          12.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3          24.51
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2          24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2          19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2          21.78
# 181       23.33  5.65    Male    Yes   Sun  Dinner     2          28.98
# 2         21.01  3.50    Male     No   Sun  Dinner     3          24.51
# 33        20.69  2.45  Female     No   Sat  Dinner     4          23.14
#
#      total_bill_tip
# 0             18.00
# 1             12.00
# 2             24.51
# 241           24.67
# 242           19.57
# 243           21.78
# 181           28.98
# 2             24.51
# 33            23.14
