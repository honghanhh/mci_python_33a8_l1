# %% [markdown]
# # Bài 7: Trực quan hoá dữ liệu với Matplotlib và Seaborn

# %% [markdown]
# ## I. GIỚI THIỆU
#
#
# Bất kì 1 thư viện nào sử dụng cho mục đích biểu diễn dữ liệu cũng sẽ theo anatomy sau.
# ![](https://matplotlib.org/stable/_images/sphx_glr_anatomy_001.png)
#
# Đây cũng là những điểm mình cần biết khi vẽ đồ thị với các thư viện trong Python.
#
# ### 1. Thư viện Matplotlib
#
# Matplotlib (cụ thể trong bài học này ta quan tâm tới gói `Matplotlib.pyplot` hay được viết gọn là `plt`) là một gói Python được sử dụng cho đồ họa 2D.
#
# Matplotlib có 2 objects chính:
# - `Figure`: chứa nhiều axes
# - `Axes`: nơi vẽ đồ thị, thực tế chính là cái đồ thị
#
# Nói 1 cách dễ hiểu, `Figure` giống khung ảnh và 1 khung ảnh có thể không chứa hoặc chứa 1 đến nhiều bức ảnh, và `Axes` tương ứng với những bức ảnh trong cái khung ảnh.
#
# Các thành phần khác:
# - `Title`: tên của đồ thị
# - `X axis label`,`Y axis label`: 2 trục (ngang, đứng) của đồ thị
# - `Major tick label`, `Minor tick label`: Tick chính chứa con số, tick nhỏ có thể hoặc không chứa con số
# - `Legend`: Chú thích
# - `Grid`: Lưới (dễ căn chỉnh)
# - `Line plot`: Đồ thị đường
# - `Scatter plot`: Đồ thị phân tán
# - `Marker`: Những chấm tròn biểu diễn điểm dữ liệu trong đồ thị phân tán
# - `Axis spine`: Đường ghi nhận ranh giới khu vực dữ liệu
# - `Spine`: Đường kết nối các dấu ticks trên trục và ghi nhận ranh giới của khu vực dữ liệu.
#
# **Tham khảo**: [Thư viện Matplotlib](https://matplotlib.org/stable/gallery/index.html)
#
# ### 2. Thư viện Seaborn
#
# Seaborn là thư viện mở rộng được viết trên nền Matplotlib, từ đó kế thừa các chức năng biểu diễn dữ liệu từ Matplotlib. Vì vậy, những gì Seaborn làm được thì Matplotlib cũng làm được tuy nhiên không có chiều ngược lại, cũng có nghĩa là Seaborn không thể thay thế hoàn toàn được Matplotlib (Seaborn hiểu đơn giản là 1 đứa con được Matplotlib tạo ra).
#
# **Tham khảo**: [Thư viện Seaborn](https://seaborn.pydata.org/examples/index.html)
#
# Mỗi thư viện đều có những ưu điểm riêng: Nếu Seaborn sử dụng ít cú pháp hơn và có các chủ đề mặc định tuyệt đẹp thì Matplotlib dễ dàng tùy chỉnh hơn thông qua việc truy cập các lớp. Và trong bài viết này, chúng ta sẽ cùng nhau khám phá vẻ đẹp của 2 thư viện.
#
# ### 3. Cài đặt
# - Cài đặt khi tạo môi trường ảo:
#
# `conda create -n hanh python=3.7 matplotlib seaborn`
#
# - Cài đặt sau khi tạo xong môi trường ảo:
#
# `conda install matplotlib` hoặc `pip install matplotlib`,
#
# `conda install seaborn` hoặc `pip install seaborn`
#
# ### 4. Import
#
# ```python
# import matplotlib.pyplot as plt
# import seaborn as sns
# ```
#
# Để bắt đầu buổi học hôm nay, chúng ta sẽ import một số thư viện phục vụ cho buổi học:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## II. CÁC KIỂU TRỰC QUAN HOÁ DỮ LIỆU CƠ BẢN
#
# ### 1. Đồ thị đường
#
# #### 1.1. Đồ thị 1 đường
#
# #### **Thực hành**: Vẽ đồ thị hình sin của 100 điểm trong khoảng từ -10 đến 10.
#
# **Gợi ý**: Cho trước giá trị x, y. Sử dụng hàm `plot()` để vẽ đồ thị đường
#
# ```python
# x = np.linspace(-10,10,100)
# y = np.sin(x)
# ```
#
# #### **Sử dụng Matplotlib**:

# %%
x = np.linspace(-10,10,100)
y = np.sin(x)

plt.plot(x,y) # vẽ biểu đồ đường
plt.title('Sin funtion')
plt.xlabel('X value')
plt.ylabel('Sin of X')
plt.show() # hiển thị biểu đồ

# %%
x = np.linspace(-10, 10, 100)
y = np.sin(x)

plt.plot(x, y, linestyle='-.')
plt.title('sin function')
plt.xlabel('X value')
plt.ylabel('Sin of X')
plt.grid()

# %%
x = np.linspace(-10,10,100)
y = np.sin(x)

plt.plot(x,y, linestyle='-.') # vẽ biểu đồ đường
plt.title('Sin funtion')
plt.xlabel('X value')
plt.ylabel('Sin of X')
plt.grid()
plt.show() # hiển thị biểu đồ

# %%
x = np.linspace(-10,10,100)
y = np.sin(x)

plt.plot(x,y, linestyle='-.', c='red') # vẽ biểu đồ đường
plt.title('Sin funtion')
plt.xlabel('X value')
plt.ylabel('Sin of X')
plt.grid()
plt.show() # hiển thị biểu đồ

# %% [markdown]
# Tham khảo 1 số cách thay đổi linestyle tại [đây](https://matplotlib.org/stable/_images/sphx_glr_linestyles_001.png).
#
# #### **Sử dụng Seaborn**:
#
# Lưu ý đầu vào của Seaborn là 1 DataDrame, còn đầu vào của đồ thị sử dụng Matplotlib là 1 Series.

# %%
df = pd.DataFrame({'x':x, 'sin':y})
df.head()
# Out:
#            x       sin
# 0 -10.000000  0.544021
# 1  -9.797980  0.364599
# 2  -9.595960  0.170347
# 3  -9.393939 -0.030834
# 4  -9.191919 -0.230760

# %%
sns.lineplot(data=df, x = df['x'], y = df['sin'])
plt.show()

# %% [markdown]
# #### 1.2 Đồ thị đa đường
#
# #### **Thực hành**: Vẽ đồ thị hình sin và hình cos của 100 điểm trong khoảng từ -10 đến 10 trên cùng 1 đồ thị.
#
# **Gợi ý**: Cho trước giá trị x, y. Sử dụng hàm `plot()` để vẽ đồ thị đường
#
# ```python
# x = np.linspace(-10,10,100)
# sin = np.sin(x)
# cos = np.cos(x)
# ```

# %%
x = np.linspace(-10,10,100)
sin = np.sin(x)
cos = np.cos(x)

# %% [markdown]
# **Cách 1**

# %%
plt.plot(x, sin, label = 'sin')
plt.plot(x, cos, label = 'cos')
plt.title('Sin/Cos function')
plt.xlabel('X value')
plt.ylabel('Sin/Cos of X')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# **Cách 2**:
# ```python
# ax.set_xlabel('X Label')
# ax.set_ylabel('Y Label')
# ax.set_title('Function plot')
# ```
# có thể được viết gọn trong 1 dòng với hàm `set()` và truyền tham số tương ứng vào bên trong như sau:
# ```python
# ax.set(xlabel='X_label', ylabel='Y_label', title='Function plot')
# ```

# %%
ax = plt.axes()
ax.plot(x,sin, label='sin')
ax.plot(x,cos, label='cos')
ax.set(xlabel= 'X_label', ylabel='Y_label', title='Function plot')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (15,5)) # Khung tranh rong => subplot vs subplots

plt.subplot(1,2,1) # so hang, so cot, axis
plt.plot(x, sin, c='red')
plt.title('Sin function')
plt.xlabel('X value')
plt.ylabel('Sin of X')

plt.subplot(1,2,2)
plt.plot(x, cos)
plt.title('Cos function')
plt.xlabel('X value')
plt.ylabel('Cos of X')

plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(15,5))
ax[0].plot(x, sin)
ax[0].set(xlabel= 'X_label', ylabel='Sin of X', title='Sin plot')
ax[1].plot(x, cos)
ax[1].set(xlabel= 'X_label', ylabel='Cos of X', title='Cos plot')
plt.show()

# %% [markdown]
# #### **Thực hành**: Vẽ đồ thị hình sin và hình cos của 100 điểm trong khoảng từ -10 đến 10 trên 2 đồ thị cạnh nhau.

# %% [markdown]
# **Cách 1**

# %%
fig, ax = plt.subplots(1,2, figsize=(15,5))
ax[0].plot(x,sin)
ax[1].plot(x,cos)
ax[1].set(xlabel = 'X_label', ylabel='Y_label', title='function')
ax[0].set(xlabel = 'X_label', ylabel='Y_label', title='function')
# Out:
# [Text(0.5, 0, 'X_label'), Text(0, 0.5, 'Y_label'), Text(0.5, 1.0, 'function')]

# %% [markdown]
# **Cách 2**

# %% [markdown]
# **Cách 2**

# %% [markdown]
# **Cách 3**

# %% [markdown]
# **Cách 3**

# %% [markdown]
# ### 2. Đồ thị phân phối (Histogram/Distribution)

# %%
iris = sns.load_dataset('iris')
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# #### **Thực hành**: Vẽ đồ thị phân phối độ dài cánh hoa tương ứng cột `sepal_length`.
#
# #### **Sử dụng Matplotlib**:

# %%
plt.hist(iris['sepal_length']) #mặc định 10 bins
plt.show()

# %%
plt.hist(iris['sepal_length'], bins=20) #bins = số cột = min & max của số liệu và chia đều số liệu
plt.show()

# %%
iris.sepal_length.describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal_length, dtype: float64

# %% [markdown]
# #### **Sử dụng Seaborn**:

# %%
sns.histplot(iris.sepal_length)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(iris, x = 'sepal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %% [markdown]
# ### 3. Đồ thị phân tán (Scatter plot)
#
# #### **Thực hành**: Vẽ đồ thị phân tán độ dài cánh hoa và đài hoa tương ứng cột `sepal_length` và `petal_length`.
#
# #### **Sử dụng Matplotlib**:

# %% [markdown]
# - Scatter plot -> shows correlation -> needs 2 datapoints

# %%
plt.scatter(iris.sepal_length,iris.petal_length)

# %%
plt.scatter(iris.petal_length,iris.petal_width)

# %% [markdown]
# Ngoài ra, ta có thể sử dụng hàm `distplot()` như ví dụ dưới đây:

# %% [markdown]
# #### **Sử dụng Seaborn**:

# %%
sns.scatterplot(data = iris, x = 'petal_length', y = 'petal_width')
sns.scatterplot(data = iris, x = 'sepal_length', y = 'sepal_width')
plt.show()

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
#cách thủ công: tạo 3 scatter plot, setosa, versicolor and virginica
plt.scatter(iris[iris.species == 'setosa'].petal_length,iris.petal_width[iris.species == 'setosa'], label = 'setosa')
plt.scatter(iris[iris.species == 'versicolor'].petal_length,iris.petal_width[iris.species == 'versicolor'], label = 'versicolor')
plt.scatter(iris[iris.species == 'virginica'].petal_length,iris.petal_width[iris.species == 'virginica'], label = 'virginica')
plt.legend()

# %% [markdown]
# ### 3. Đồ thị phân tán (Scatter plot)
#
# #### **Thực hành**: Vẽ đồ thị phân tán độ dài cánh hoa và đài hoa tương ứng cột `sepal_length` và `petal_length`.
#
# #### **Sử dụng Matplotlib**:

# %%
sns.scatterplot(data=iris, x='petal_length', y='petal_width', hue='species', palette=['red','blue','brown'])
plt.show()

# %%
plt.scatter(iris.petal_length,iris.petal_width, marker = '*', label = 'petal')
plt.scatter(iris.sepal_length,iris.sepal_width, label = 'sepal')
plt.legend()
plt.show()

# %% [markdown]
# ### 4. Đồ thị hộp (Box plot)
#
# #### **Thực hành**: Vẽ biểu đồ hộp độ dài đài hoa tương ứng cột `petal_length`.

# %%
iris.petal_length.describe()
#mean not equal to median (50%) -> not normal distribution
# Out:
# count    150.000000
# mean       3.758000
# std        1.765298
# min        1.000000
# 25%        1.600000
# 50%        4.350000
# 75%        5.100000
# max        6.900000
# Name: petal_length, dtype: float64

# %%
plt.boxplot(iris.petal_length, vert=False) #vert=True hoặc k viết gì -> nằm dọc
plt.show()

# %%
sns.boxplot(data=iris, x='petal_length', width=0.2) #muốn boxplot nằm dọc thì chuyển x thành y
# Out:
# <AxesSubplot:xlabel='petal_length'>

# %% [markdown]
# #### **Thực hành**: Vẽ biểu đồ hộp các cột dữ liệu trong `iris`.
# #### **Sử dụng Matplotlib**:

# %%
# các cái tròn bên ngoài = outlier
plt.boxplot([iris['petal_length'],iris['petal_width'],iris['sepal_length'],iris['sepal_width']], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c4b29bb108>,
#   <matplotlib.lines.Line2D at 0x1c4b2a4bcc8>,
#   <matplotlib.lines.Line2D at 0x1c4b29f6208>,
#   <matplotlib.lines.Line2D at 0x1c4b2923e88>,
#   <matplotlib.lines.Line2D at 0x1c4b29de288>,
#   <matplotlib.lines.Line2D at 0x1c4b29c75c8>,
#   <matplotlib.lines.Line2D at 0x1c4b29cfa48>,
#   <matplotlib.lines.Line2D at 0x1c4b29b0748>],
#  'caps': [<matplotlib.lines.Line2D at 0x1c4b29bbf08>,
#   <matplotlib.lines.Line2D at 0x1c4b29f69c8>,
#   <matplotlib.lines.Line2D at 0x1c4b2ae2588>,
#   <matplotlib.lines.Line2D at 0x1c4b29ab1c8>,
#   <matplotlib.lines.Line2D at 0x1c4b2942448>,
#   <matplotlib.lines.Line2D at 0x1c4b29d8188>,
#   <matplotlib.lines.Line2D at 0x1c4b298be88>,
#   <matplotlib.lines.Line2D at 0x1c4b2991188>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1c4b29cf6c8>,
#   <matplotlib.lines.Line2D at 0x1c4b29bbbc8>,
#   <matplotlib.lines.Line2D at 0x1c4b2923308>,
#   <matplotlib.lines.Line2D at 0x1c4b29c7508>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c4b29bb708>,
#   <matplotlib.lines.Line2D at 0x1c4b2942548>,
#   <matplotlib.lines.Line2D at 0x1c4b298be08>,
#   <matplotlib.lines.Line2D at 0x1c4b29b0248>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c4b29bb208>,
#   <matplotlib.lines.Line2D at 0x1c4b29234c8>,
#   <matplotlib.lines.Line2D at 0x1c4b29c7e48>,
#   <matplotlib.lines.Line2D at 0x1c4b29b0f88>],
#  'means': []}

# %% [markdown]
# #### **Sử dụng Seaborn**:

# %%
sns.boxplot(data=iris)
plt.show()

# %% [markdown]
# Ngoài ra, chúng ta có 1 vài hàm biến thể nhằm trực quan hoá mô tả phân bố dữ liệu, tham khảo 1 số hàm dưới đây:

# %%
sns.boxenplot(data=iris) # boxenplot dùng khi cần thêm số bins, cụm giá trị ở bin nào to hơn -> phân bố các cụm giá trị
plt.show()

# %%
sns.violinplot(data=iris) # violin dùng để xem curve phân bố tập trung ở đâu, vd: vàng tập trung đối xứng
plt.show()

# %% [markdown]
# ### 5. Biểu đồ tròn (Pie chart)

# %%
tips = sns.load_dataset('tips')
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# #### **Thực hành**: Vẽ biểu đồ tròn thể hiện giới tính nam và nữ chiếm bao nhiêu phần trăm trong tổng hoá đơn.

# %%
#Male: total_bill
#Female: total_bill
tips.groupby('sex').total_bill.sum()
# Out:
# sex
# Male      3256.82
# Female    1570.95
# Name: total_bill, dtype: float64

# %% [markdown]
# #### **Sử dụng Matplotlib**:

# %%
sex = tips.groupby('sex').total_bill.sum()
plt.pie(sex, labels = sex.index, autopct = '%.2f%%') #2f = 2 float 
plt.legend()
plt.show()

# %%
sex.index
# Out:
# CategoricalIndex(['Male', 'Female'], categories=['Male', 'Female'], ordered=False, dtype='category', name='sex')

# %% [markdown]
# #### **Sử dụng Seaborn**:
# Seaborn thì không hỗ trợ trực tiếp **pie chart**, ta có thể sử dụng **bar plot chart** thay thế.

# %%
sex1 = pd.DataFrame(sex).reset_index()
sex1
# Out:
#       sex  total_bill
# 0    Male     3256.82
# 1  Female     1570.95

# %%
sns.barplot(data=sex1, x='sex', y='total_bill')
plt.show()

# %% [markdown]
# Ta cũng có thể sử dụng barplot với thư viện Matplotlib và Pandas như dưới đây:

# %%
plt.bar(data=sex1, x='sex', height='total_bill', color = ['black','pink'])
plt.show()

# %%
sex1.plot.bar()
plt.show()

# %%
sex1.plot(kind='bar')
plt.show()

# %%
sex1.plot(kind='barh') #h for horizontal
plt.show()

# %% [markdown]
# **Bonus**: Ta có thể sử dụng `countplot()` để đếm số lượng, ví dụ:

# %%
sns.countplot(data=tips, x='sex')
plt.show()

# %% [markdown]
# #### **BTVN**: Vẽ biểu đồ tròn thể hiện giới tính nam và nữ chiếm bao nhiêu phần trăm trong tổng hoá đơn (total_bill) phía bên trái và biểu đồ tròn thể hiện tổng hoá đơn tiêu thụ theo ngày phía bên phải.

# %%
plt.pie(data=sex1, x='total_bill', labels='sex', autopct = '%.2f%%') # x='total_bill' -> what I'm trying to portrait here
plt.title('Total bills by gender')
plt.legend()
plt.show()

# %%
weekday = tips.groupby('day').total_bill.sum()
weekday.head()
# Out:
# day
# Thur    1096.33
# Fri      325.88
# Sat     1778.40
# Sun     1627.16
# Name: total_bill, dtype: float64

# %%
plt.pie(weekday, labels = weekday.index, autopct = '%.2f%%', explode = [0,0.2,0,0])
plt.title('Total bills by weekday')
plt.legend()
plt.show()

# %% [markdown]
# #### **Bài tập**: Vẽ biểu đồ tròn thể hiện phần trăm tổng hoá đơn tiêu thụ của nam theo ngày.

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#sex=Male
#total_bill sum daily 
#graph into piechart

# %%
male = tips[tips['sex'] == 'Male'].groupby('day').total_bill.sum()  # nếu có nhiều condition thì cho hết vào () rồi & 
male.head(5)
# Out:
# day
# Thur     561.44
# Fri      198.57
# Sat     1227.35
# Sun     1269.46
# Name: total_bill, dtype: float64

# %%
plt.pie(male, labels = male.index, autopct = '%.2f%%', explode = [0,1,0,0])
plt.show()

# %%
plt.pie(male, labels = male.index, autopct = '%.2f%%', explode = [0,0.2,0,0])
plt.show()

# %% [markdown]
# ### 6. Một số biểu đồ tương quan phức hợp (Giới thiệu)

# %% [markdown]
# Trong bài học tiếp theo, chúng ta sẽ cùng nhau tìm hiểu về Học máy, các bài toán trong Học máy và tiếp cận đến loại bài toán đầu tiên trong Học máy, đó là Học có giám sát.

# %%
# FacetGrid -> Tidy (“long-form”) dataframe where each column is a variable and each row is an observation
FGrid = sns.FacetGrid(data=tips, col = 'sex', row = 'smoker', hue='time')
FGrid.map(sns.scatterplot, 'total_bill', 'tip')
plt.legend()
plt.show()

# %%
#pairplot -> show 2 cặp một trong dữ liệu thì hành vi ntn, Plot pairwise relationships in a dataset
sns.pairplot(iris, hue='species', height=1.5)
plt.show()
