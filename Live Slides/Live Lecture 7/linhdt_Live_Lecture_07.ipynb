# %% [markdown]
# # Bài 7: Trực quan hoá dữ liệu với Matplotlib và Seaborn

# %% [markdown]
# ## I. GIỚI THIỆU
#
#
# Bất kì 1 thư viện nào sử dụng cho mục đích biểu diễn dữ liệu cũng sẽ theo anatomy sau.
# ![](https://matplotlib.org/stable/_images/sphx_glr_anatomy_001.png)
#
# Đây cũng là những điểm mình cần biết khi vẽ đồ thị với các thư viện trong Python.
#
# ### 1. Thư viện Matplotlib
#
# Matplotlib (cụ thể trong bài học này ta quan tâm tới gói `Matplotlib.pyplot` hay được viết gọn là `plt`) là một gói Python được sử dụng cho đồ họa 2D.
#
# Matplotlib có 2 objects chính:
# - `Figure`: chứa nhiều axes
# - `Axes`: nơi vẽ đồ thị, thực tế chính là cái đồ thị
#
# Nói 1 cách dễ hiểu, `Figure` giống khung ảnh và 1 khung ảnh có thể không chứa hoặc chứa 1 đến nhiều bức ảnh, và `Axes` tương ứng với những bức ảnh trong cái khung ảnh.
#
# Các thành phần khác:
# - `Title`: tên của đồ thị
# - `X axis label`,`Y axis label`: 2 trục (ngang, đứng) của đồ thị
# - `Major tick label`, `Minor tick label`: Tick chính chứa con số, tick nhỏ có thể hoặc không chứa con số
# - `Legend`: Chú thích
# - `Grid`: Lưới (dễ căn chỉnh)
# - `Line plot`: Đồ thị đường
# - `Scatter plot`: Đồ thị phân tán
# - `Marker`: Những chấm tròn biểu diễn điểm dữ liệu trong đồ thị phân tán
# - `Axis spine`: Đường ghi nhận ranh giới khu vực dữ liệu
# - `Spine`: Đường kết nối các dấu ticks trên trục và ghi nhận ranh giới của khu vực dữ liệu.
#
# **Tham khảo**: [Thư viện Matplotlib](https://matplotlib.org/stable/gallery/index.html)
#
# ### 2. Thư viện Seaborn
#
# Seaborn là thư viện mở rộng được viết trên nền Matplotlib, từ đó kế thừa các chức năng biểu diễn dữ liệu từ Matplotlib. Vì vậy, những gì Seaborn làm được thì Matplotlib cũng làm được tuy nhiên không có chiều ngược lại, cũng có nghĩa là Seaborn không thể thay thế hoàn toàn được Matplotlib (Seaborn hiểu đơn giản là 1 đứa con được Matplotlib tạo ra).
#
# **Tham khảo**: [Thư viện Seaborn](https://seaborn.pydata.org/examples/index.html)
#
# Mỗi thư viện đều có những ưu điểm riêng: Nếu Seaborn sử dụng ít cú pháp hơn và có các chủ đề mặc định tuyệt đẹp thì Matplotlib dễ dàng tùy chỉnh hơn thông qua việc truy cập các lớp. Và trong bài viết này, chúng ta sẽ cùng nhau khám phá vẻ đẹp của 2 thư viện.
#
# ### 3. Cài đặt
# - Cài đặt khi tạo môi trường ảo:
#
# `conda create -n hanh python=3.7 matplotlib seaborn`
#
# - Cài đặt sau khi tạo xong môi trường ảo:
#
# `conda install matplotlib` hoặc `pip install matplotlib`,
#
# `conda install seaborn` hoặc `pip install seaborn`
#
# ### 4. Import
#
# ```python
# import matplotlib.pyplot as plt
# import seaborn as sns
# ```
#
# Để bắt đầu buổi học hôm nay, chúng ta sẽ import một số thư viện phục vụ cho buổi học:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## II. CÁC KIỂU TRỰC QUAN HOÁ DỮ LIỆU CƠ BẢN
#
# ### 1. Đồ thị đường
#
# #### 1.1. Đồ thị 1 đường
#
# #### **Thực hành**: Vẽ đồ thị hình sin của 100 điểm trong khoảng từ -10 đến 10.
#
# **Gợi ý**: Cho trước giá trị x, y. Sử dụng hàm `plot()` để vẽ đồ thị đường
#
# ```python
# x = np.linspace(-10,10,100)
# y = np.sin(x)
# ```
#
# #### **Sử dụng Matplotlib**:

# %%
x= np.linspace(-10,10,100)
y= np.sin(x)

# %%
plt.plot(x,y, linestyle='-.', c='blue')
plt.title("sin function")
plt.xlabel("X value")
plt.ylabel("Sin of X")
plt.grid()

# %% [markdown]
# Tham khảo 1 số cách thay đổi linestyle tại [đây](https://matplotlib.org/stable/_images/sphx_glr_linestyles_001.png).
#
# #### **Sử dụng Seaborn**:
#
# Lưu ý đầu vào của Seaborn là 1 DataDrame, còn đầu vào của đồ thị sử dụng Matplotlib là 1 Series.

# %%
df=pd.DataFrame({'x':x,'sin':y})
df.head(5)
# Out:
#            x       sin
# 0 -10.000000  0.544021
# 1  -9.797980  0.364599
# 2  -9.595960  0.170347
# 3  -9.393939 -0.030834
# 4  -9.191919 -0.230760

# %%
sns.lineplot(data=df, x=df['x'], y=df['sin'])
# Out:
# <AxesSubplot:xlabel='x', ylabel='sin'>

# %% [markdown]
# #### 1.2 Đồ thị đa đường
#
# #### **Thực hành**: Vẽ đồ thị hình sin và hình cos của 100 điểm trong khoảng từ -10 đến 10 trên cùng 1 đồ thị.
#
# **Gợi ý**: Cho trước giá trị x, y. Sử dụng hàm `plot()` để vẽ đồ thị đường
#
# ```python
# x = np.linspace(-10,10,100)
# sin = np.sin(x)
# cos = np.cos(x)
# ```

# %%
x= np.linspace(-10,10,100)
sin=np.sin(x)
cos=np.cos(x)

# %% [markdown]
# **Cách 1**

# %%
plt.plot(x,sin, label = 'sin')
plt.plot(x,cos, label= 'cos')
plt.title("sin/cos function")
plt.xlabel("X value")
plt.ylabel("Sin/Cos of X")
plt.legend(loc='best')
# không gán biến nào cả

# %% [markdown]
# **Cách 2**:
# ```python
# ax.set_xlabel('X Label')
# ax.set_ylabel('Y Label')
# ax.set_title('Function plot')
# ```
# có thể được viết gọn trong 1 dòng với hàm `set()` và truyền tham số tương ứng vào bên trong như sau:
# ```python
# ax.set(xlabel='X_label', ylabel='Y_label', title='Function plot')
# ```

# %%
ax= plt.axes() #nơi vẽ đồ thị có trục tung, trục hoành
ax.plot(x,sin, label= 'sin')
ax.plot(x,cos, label= 'cos')
plt.legend()
ax.set(xlabel='X_label', ylabel='Y_label', title='Function plot')
# Out:
# [Text(0.5, 0, 'X_label'),
#  Text(0, 0.5, 'Y_label'),
#  Text(0.5, 1.0, 'Function plot')]

# %%
plt.figure(figsize= (15,5))# khung tranh rỗng, đồ dài trục hoành, tung

# %%
# tạo ra bức tranh con trong khung tramh 2 cách : subplot vs subplots

# %%
# tạo ra 1 tranh con cho sin
plt.subplot(1,2,1) # so hang, cot của khung tranh, axis vi trí tranh, vị trí của tranh
plt.plot(x,sin,c='red')
plt.title("sin function")
plt.xlabel("X value")
plt.ylabel("Sin of X")
# tạo ra 1 tranh con cho cos
plt.subplot(1,2,2)
plt.plot(x,cos)
plt.title("cos function")
plt.xlabel("X value")
plt.ylabel("Cos of X")
# 1 hàng duy nhất, 2 cột, vj trí tranh ở cột 1, vị trí tranh ở cột 2
# Out:
# Text(0, 0.5, 'Cos of X')

# %%
fig, ax= plt.subplots(1,2, figsize=(15,5))
ax[0].plot(x,sin)
ax[0].set(xlabel='X_label', ylabel='sin', title='Function plot')
ax[1].plot(x,cos)
ax[1].set(xlabel='X_label', ylabel='cos', title='Function plot')
# Out:
# [Text(0.5, 0, 'X_label'), Text(0, 0.5, 'cos'), Text(0.5, 1.0, 'Function plot')]

# %% [markdown]
# #### **Thực hành**: Vẽ đồ thị hình sin và hình cos của 100 điểm trong khoảng từ -10 đến 10 trên 2 đồ thị cạnh nhau.

# %% [markdown]
# **Cách 1**

# %% [markdown]
# **Cách 2**

# %% [markdown]
# **Cách 3**

# %% [markdown]
# ### 2. Đồ thị phân phối (Histogram/Distribution)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# #### **Thực hành**: Vẽ đồ thị phân phối độ dài cánh hoa tương ứng cột `sepal_length`.
#
# #### **Sử dụng Matplotlib**:

# %%
plt.hist(iris['sepal_length'], bins=20)
# Out:
# (array([ 4.,  5.,  7., 16.,  9.,  5., 13., 14., 10.,  6., 10., 16.,  7.,
#         11.,  4.,  2.,  4.,  1.,  5.,  1.]),
#  array([4.3 , 4.48, 4.66, 4.84, 5.02, 5.2 , 5.38, 5.56, 5.74, 5.92, 6.1 ,
#         6.28, 6.46, 6.64, 6.82, 7.  , 7.18, 7.36, 7.54, 7.72, 7.9 ]),
#  <BarContainer object of 20 artists>)

# %%
iris['sepal_length'].describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal_length, dtype: float64

# %% [markdown]
# #### **Sử dụng Seaborn**:

# %%
sns.histplot(iris['sepal_length'])
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(iris, x='sepal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %% [markdown]
# Ngoài ra, ta có thể sử dụng hàm `distplot()` như ví dụ dưới đây:

# %% [markdown]
# ### 3. Đồ thị phân tán (Scatter plot)
#
# #### **Thực hành**: Vẽ đồ thị phân tán độ dài cánh hoa và đài hoa tương ứng cột `sepal_length` và `petal_length`.
#
# #### **Sử dụng Matplotlib**:

# %%
plt.scatter(iris.sepal_length,iris.petal_length)

# %% [markdown]
# #### **Sử dụng Seaborn**:

# %%
sns.scatterplot(data=iris, x='petal_length', y='petal_width')
sns.scatterplot(data=iris, x='sepal_length',y='sepal_width')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %% [markdown]
# #### **Thực hành**: Vẽ đồ thị phân tán độ dài và độ rộng đài hoa tương ứng cột `petal_length`.
#
# #### **Sử dụng Matplotlib**:

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.scatter(iris.petal_length,iris.petal_width)

# %%
# 3 scatter plot: setosa,ver, ving
plt.scatter(iris[iris.species=='setosa'].petal_length, iris[iris.species=='setosa'].petal_width,label='vetosa')
plt.scatter(iris[iris.species=='versicolor'].petal_length, iris[iris.species=='versicolor'].petal_width,label='versicolor')
plt.scatter(iris[iris.species=='virginica'].petal_length, iris[iris.species=='virginica'].petal_width, label='virginica')
plt.legend()

# %% [markdown]
# #### **Sử dụng Seaborn**:

# %%
sns,scatterplot(data=iris, x='petal_length',y='petal_length'

# %% [markdown]
# ### 4. Đồ thị hộp (Box plot)
#
# #### **Thực hành**: Vẽ biểu đồ hộp độ dài đài hoa tương ứng cột `petal_length`.

# %%
# Out:
# count    150.000000
# mean       3.758000
# std        1.765298
# min        1.000000
# 25%        1.600000
# 50%        4.350000
# 75%        5.100000
# max        6.900000
# Name: petal_length, dtype: float64

# %%
plt.boxplot(iris['petal_length'],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24125050130>,
#   <matplotlib.lines.Line2D at 0x2412503df40>],
#  'caps': [<matplotlib.lines.Line2D at 0x2412503d160>,
#   <matplotlib.lines.Line2D at 0x2412503d670>],
#  'boxes': [<matplotlib.lines.Line2D at 0x24125050d60>],
#  'medians': [<matplotlib.lines.Line2D at 0x2412503db50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2412502fe20>],
#  'means': []}

# %% [markdown]
# #### **Thực hành**: Vẽ biểu đồ hộp các cột dữ liệu trong `iris`.
# #### **Sử dụng Matplotlib**:

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
plt.boxplot([iris['petal_length'],iris['sepal_length'],iris['sepal_width'],iris['petal_width']],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2412552abb0>,
#   <matplotlib.lines.Line2D at 0x2412552af40>,
#   <matplotlib.lines.Line2D at 0x24125548520>,
#   <matplotlib.lines.Line2D at 0x241255488b0>,
#   <matplotlib.lines.Line2D at 0x24125552e50>,
#   <matplotlib.lines.Line2D at 0x2412555f220>,
#   <matplotlib.lines.Line2D at 0x241255697c0>,
#   <matplotlib.lines.Line2D at 0x24125569b50>],
#  'caps': [<matplotlib.lines.Line2D at 0x24125539310>,
#   <matplotlib.lines.Line2D at 0x241255396a0>,
#   <matplotlib.lines.Line2D at 0x24125548c40>,
#   <matplotlib.lines.Line2D at 0x24125548fd0>,
#   <matplotlib.lines.Line2D at 0x2412555f5b0>,
#   <matplotlib.lines.Line2D at 0x2412555f940>,
#   <matplotlib.lines.Line2D at 0x24125569ee0>,
#   <matplotlib.lines.Line2D at 0x241255732b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2412552a820>,
#   <matplotlib.lines.Line2D at 0x24125548190>,
#   <matplotlib.lines.Line2D at 0x24125552ac0>,
#   <matplotlib.lines.Line2D at 0x24125569430>],
#  'medians': [<matplotlib.lines.Line2D at 0x24125539a30>,
#   <matplotlib.lines.Line2D at 0x241255523a0>,
#   <matplotlib.lines.Line2D at 0x2412555fcd0>,
#   <matplotlib.lines.Line2D at 0x24125573640>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24125539dc0>,
#   <matplotlib.lines.Line2D at 0x24125552730>,
#   <matplotlib.lines.Line2D at 0x241255690a0>,
#   <matplotlib.lines.Line2D at 0x241255739d0>],
#  'means': []}

# %% [markdown]
# #### **Sử dụng Seaborn**:

# %%
sns.boxplot(data=iris,y='petal_length',width=0.2)
# Out:
# <AxesSubplot:ylabel='petal_length'>

# %% [markdown]
# Ngoài ra, chúng ta có 1 vài hàm biến thể nhằm trực quan hoá mô tả phân bố dữ liệu, tham khảo 1 số hàm dưới đây:

# %%
sns.boxplot(data=iris)
# Out:
# <AxesSubplot:>

# %%
sns.boxenplot(data=iris)
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(data=iris)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 5. Biểu đồ tròn (Pie chart)

# %%
tips=sns.load_dataset('tips')
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# #### **Thực hành**: Vẽ biểu đồ tròn thể hiện giới tính nam và nữ chiếm bao nhiêu phần trăm trong tổng hoá đơn.

# %%
# 2 gioi ting, tổng total_bill nam , nu
sex=tips.groupby('sex').total_bill.sum()

# %%
sex1=pd.DataFrame(sex)

# %% [markdown]
# #### **Sử dụng Matplotlib**:

# %%
plt.pie(sex, labels = sex.index, autopct = '%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x24127920f10>,
#   <matplotlib.patches.Wedge at 0x24127901b20>],
#  [Text(-0.5735732444629189, 0.9386233180761496, 'Male'),
#   Text(0.5735732444629191, -0.9386233180761495, 'Female')],
#  [Text(-0.3128581333434103, 0.5119763553142634, '67.46%'),
#   Text(0.3128581333434104, -0.5119763553142633, '32.54%')])

# %% [markdown]
# #### **Sử dụng Seaborn**:
# Seaborn thì không hỗ trợ trực tiếp **pie chart**, ta có thể sử dụng **bar plot chart** thay thế.

# %%
sns.barplot(data= sex1, x='sex', y='total_bill')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7008/2706552712.py in <module>
# ----> 1 sns.barplot(data= sex1, x='sex', y='total_bill')
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3183                           estimator, ci, n_boot, units, seed,
#    3184                           orient, color, palette, saturation,
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'sex'

# %% [markdown]
# Ta cũng có thể sử dụng barplot với thư viện Matplotlib và Pandas như dưới đây:

# %%
sex1.plot.bar()
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
sex1.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %% [markdown]
# **Bonus**: Ta có thể sử dụng `countplot()` để đếm số lượng, ví dụ:

# %%
sns.countplot(data=tips,x='sex')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# #### **Thực hành**: Vẽ biểu đồ tròn thể hiện giới tính nam và nữ chiếm bao nhiêu phần trăm trong tổng hoá đơn phía bên trái và biểu đồ tròn thể hiện tổng hoá đơn tiêu thụ theo ngày phía bên phải.

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
day=tips.groupby('day').total_bill.sum()

# %%
plt.pie(day, labels = day.index, autopct = '%.2f%%', explode=[0,0.1,0,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x241291314c0>,
#   <matplotlib.patches.Wedge at 0x24129131c40>,
#   <matplotlib.patches.Wedge at 0x2412913f3a0>,
#   <matplotlib.patches.Wedge at 0x2412913faf0>],
#  [Text(0.8317418198604141, 0.7198649492059511, 'Thur'),
#   Text(-0.08165980109322299, 1.1972183079478094, 'Fri'),
#   Text(-1.0902316372510155, 0.1462702195833805, 'Sat'),
#   Text(0.5388644448471241, -0.9589708598698924, 'Sun')],
#  [Text(0.4536773562874985, 0.3926536086577915, '22.71%'),
#   Text(-0.04763488397104674, 0.6983773463028886, '6.75%'),
#   Text(-0.5946718021369175, 0.07978375613638934, '36.84%'),
#   Text(0.29392606082570405, -0.5230750144744867, '33.70%')])

# %% [markdown]
# #### **Bài tập**: Vẽ biểu đồ tròn thể hiện giới phần trăm tổng hoá đơn tiêu thụ của nam theo ngày.

# %%
male=tips[tips['sex']=='Male'].groupby('day').total_bill.sum()

# %%
plt.pie(male,labels= male.index,autopct='%.2f%%', explode=[0,0.2 ,0 ,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x24129078730>,
#   <matplotlib.patches.Wedge at 0x24129078eb0>,
#   <matplotlib.patches.Wedge at 0x24129087640>,
#   <matplotlib.patches.Wedge at 0x24129087d60>],
#  [Text(0.9425870087134841, 0.5670359168558606, 'Thur'),
#   Text(0.3793292537555331, 1.243426442233424, 'Fri'),
#   Text(-0.969827266069502, 0.5190713573181971, 'Sat'),
#   Text(0.3733104737357794, -1.034717009717714, 'Sun')],
#  [Text(0.514138368389173, 0.30929231828501486, '17.24%'),
#   Text(0.23343338692648186, 0.7651855029128763, '6.10%'),
#   Text(-0.5289966905833646, 0.2831298312644711, '37.69%'),
#   Text(0.20362389476497056, -0.5643910962096622, '38.98%')])

# %% [markdown]
# ### 6. Một số biểu đồ tương quan phức hợp (Giới thiệu)

# %% [markdown]
# Trong bài học tiếp theo, chúng ta sẽ cùng nhau tìm hiểu về Học máy, các bài toán trong Học máy và tiếp cận đến loại bài toán đầu tiên trong Học máy, đó là Học có giám sát.

# %%
# FacetGrid thư viện
g=sns.FacetGrid(data=tips,col ='sex', row='smoker',hue='time')
g.map(sns.scatterplot,'total_bill','tip')

# %%
#pairplot
sns.pairplot(iris,hue='species')
