# %% [markdown]
# # Bài 7: Trực quan hoá dữ liệu với Matplotlib và Seaborn

# %% [markdown]
# ## I. GIỚI THIỆU
#
#
# Bất kì 1 thư viện nào sử dụng cho mục đích biểu diễn dữ liệu cũng sẽ theo anatomy sau.
# ![](https://matplotlib.org/stable/_images/sphx_glr_anatomy_001.png)
#
# Đây cũng là những điểm mình cần biết khi vẽ đồ thị với các thư viện trong Python.
#
# ### 1. Thư viện Matplotlib
#
# Matplotlib (cụ thể trong bài học này ta quan tâm tới gói `Matplotlib.pyplot` hay được viết gọn là `plt`) là một gói Python được sử dụng cho đồ họa 2D.
#
# Matplotlib có 2 objects chính:
# - `Figure`: chứa nhiều axes
# - `Axes`: nơi vẽ đồ thị, thực tế chính là cái đồ thị
#
# Nói 1 cách dễ hiểu, `Figure` giống khung ảnh và 1 khung ảnh có thể không chứa hoặc chứa 1 đến nhiều bức ảnh, và `Axes` tương ứng với những bức ảnh trong cái khung ảnh.
#
# Các thành phần khác:
# - `Title`: tên của đồ thị
# - `X axis label`,`Y axis label`: 2 trục (ngang, đứng) của đồ thị
# - `Major tick label`, `Minor tick label`: Tick chính chứa con số, tick nhỏ có thể hoặc không chứa con số
# - `Legend`: Chú thích
# - `Grid`: Lưới (dễ căn chỉnh)
# - `Line plot`: Đồ thị đường
# - `Scatter plot`: Đồ thị phân tán
# - `Marker`: Những chấm tròn biểu diễn điểm dữ liệu trong đồ thị phân tán
# - `Axis spine`: Đường ghi nhận ranh giới khu vực dữ liệu
# - `Spine`: Đường kết nối các dấu ticks trên trục và ghi nhận ranh giới của khu vực dữ liệu.
#
# **Tham khảo**: [Thư viện Matplotlib](https://matplotlib.org/stable/gallery/index.html)
#
# ### 2. Thư viện Seaborn
#
# Seaborn là thư viện mở rộng được viết trên nền Matplotlib, từ đó kế thừa các chức năng biểu diễn dữ liệu từ Matplotlib. Vì vậy, những gì Seaborn làm được thì Matplotlib cũng làm được tuy nhiên không có chiều ngược lại, cũng có nghĩa là Seaborn không thể thay thế hoàn toàn được Matplotlib (Seaborn hiểu đơn giản là 1 đứa con được Matplotlib tạo ra).
#
# **Tham khảo**: [Thư viện Seaborn](https://seaborn.pydata.org/examples/index.html)
#
# Mỗi thư viện đều có những ưu điểm riêng: Nếu Seaborn sử dụng ít cú pháp hơn và có các chủ đề mặc định tuyệt đẹp thì Matplotlib dễ dàng tùy chỉnh hơn thông qua việc truy cập các lớp. Và trong bài viết này, chúng ta sẽ cùng nhau khám phá vẻ đẹp của 2 thư viện.
#
# ### 3. Cài đặt
# - Cài đặt khi tạo môi trường ảo:
#
# `conda create -n hanh python=3.7 matplotlib seaborn`
#
# - Cài đặt sau khi tạo xong môi trường ảo:
#
# `conda install matplotlib` hoặc `pip install matplotlib`,
#
# `conda install seaborn` hoặc `pip install seaborn`
#
# ### 4. Import
#
# ```python
# import matplotlib.pyplot as plt
# import seaborn as sns
# ```
#
# Để bắt đầu buổi học hôm nay, chúng ta sẽ import một số thư viện phục vụ cho buổi học:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ## II. CÁC KIỂU TRỰC QUAN HOÁ DỮ LIỆU CƠ BẢN
#
# ### 1. Đồ thị đường
#
# #### 1.1. Đồ thị 1 đường
#
# #### **Thực hành**: Vẽ đồ thị hình sin của 100 điểm trong khoảng từ -10 đến 10.
#
# **Gợi ý**: Cho trước giá trị x, y. Sử dụng hàm `plot()` để vẽ đồ thị đường
#
# ```python
# x = np.linspace(-10,10,100)
# y = np.sin(x)
# ```
#
# #### **Sử dụng Matplotlib**:

# %%
x= np.linspace(-10, 10, 100)
y= np.sin(x)
#muốn vẽ đồ thị đường thì dùng câu lệnh
plt.plot(x, y, linestyle='-.', c= 'yellow')
plt.title('Sin function') #truyền str vào
plt.xlabel('X value')
plt.ylabel('Sin of X')
plt.grid() # tạo lưới

# %%
plt.plot(x, y, linestyle='solid', c= 'yellow')
plt.title('Sin function') #truyền str vào
plt.xlabel('X value')
plt.ylabel('Sin of X')
plt.grid() # tạo lưới

# %%
#tạo tên đồ thị, tên trục hoành, trục tung

# %% [markdown]
# Tham khảo 1 số cách thay đổi linestyle tại [đây](https://matplotlib.org/stable/_images/sphx_glr_linestyles_001.png).
#
# #### **Sử dụng Seaborn**:
#
# Lưu ý đầu vào của Seaborn là 1 DataDrame, còn đầu vào của đồ thị sử dụng Matplotlib là 1 Series.

# %%
#đầu vào là 1 chuỗi series, ngoài ra còn có cả dầu vào là Data Frame nữa.
df= pd.DataFrame({'x': x, 'sin': y})
df.head()
# Out:
#            x       sin
# 0 -10.000000  0.544021
# 1  -9.797980  0.364599
# 2  -9.595960  0.170347
# 3  -9.393939 -0.030834
# 4  -9.191919 -0.230760

# %%
sns.lineplot(data=df, x=df['x'], y=df['sin'])
# Out:
# <AxesSubplot:xlabel='x', ylabel='sin'>

# %%
sns.lineplot(data=df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 1.2 Đồ thị đa đường
#
# #### **Thực hành**: Vẽ đồ thị hình sin và hình cos của 100 điểm trong khoảng từ -10 đến 10 trên cùng 1 đồ thị.
#
# **Gợi ý**: Cho trước giá trị x, y. Sử dụng hàm `plot()` để vẽ đồ thị đường
#
# ```python
# x = np.linspace(-10,10,100)
# sin = np.sin(x)
# cos = np.cos(x)
# ```

# %% [markdown]
# sin và cos luôn cách nhau 1 khoảng pi/2

# %%
x = np.linspace(-10,10,100)
sin = np.sin(x)
cos = np.cos(x)

# %% [markdown]
# **Cách 1**

# %%
plt.plot(x, sin, label='sin')
plt.plot(x, cos, label= 'cos')
plt.title('Sin/Cos function') #truyền str vào
plt.xlabel('X value')
plt.ylabel('Sin of X')
plt.grid() # tạo lưới
plt.legend(loc='best')

# %% [markdown]
# **Cách 2**:
# ```python
# ax.set_xlabel('X Label')
# ax.set_ylabel('Y Label')
# ax.set_title('Function plot')
# ```
# có thể được viết gọn trong 1 dòng với hàm `set()` và truyền tham số tương ứng vào bên trong như sau:
# ```python
# ax.set(xlabel='X_label', ylabel='Y_label', title='Function plot')
# ```

# %%
#tạo ra trước 1 khung tranh,
ax =plt.axes() #=> tạo đồ thị rỗng chưa truyền giá trị, 
#bản chất là định nghĩa nơi tạo đồ thị.

# %%
ax =plt.axes()
ax.plot(x, sin, label='sin')
ax.plot(x, cos, label= 'cos')
ax.set(xlabel='X_label', ylabel='Y_label', title='Function plot')
plt.legend()
# thích dùng hơn axes, vì khi định nghĩa dưới dạng axes thì gói gọn trogn 1 hàm, tên là set trả về chức năng giống 
#như ba dòng lệnh ở trên

# %%
plt.figure(figsize =(15, 5) ) # tạo khung tranh rỗng -> subplot vs subplots. figsize= cố định độ dài, độ rộng của bức tranh
# 1 tranh con cho sin
plt.subplot(1, 2, 1) # số hàng, số cột, axis-vị trí của tranh 
plt.plot(x, sin, c='red')
plt.title('Sin function') #truyền str vào
plt.xlabel('X value')
plt.ylabel('Sin of X')
# 1 tranh con cho cos
plt.subplot (1, 2, 2)
plt.plot(x, cos, c='pink')
plt.title('Cos function') #truyền str vào
plt.xlabel('X value')
plt.ylabel('Cos of X')
# Out:
# Text(0, 0.5, 'Cos of X')

# %%
fig, ax=plt.subplots(1, 2, figsize=(15, 5))
#khi muốn vẽ đồ thị thì gọi đồ thị con ra thông qua biến ax
ax[0].plot(x, sin)
ax[0].set(xlabel='X_label', ylabel='Y_label', title='Sin plot')
ax[1].plot(x, cos)
ax[1].set(xlabel='X_label', ylabel='Y_label', title='Cos plot')
# Out:
# [Text(0.5, 0, 'X_label'), Text(0, 0.5, 'Y_label'), Text(0.5, 1.0, 'Cos plot')]

# %% [markdown]
# #### **Thực hành**: Vẽ đồ thị hình sin và hình cos của 100 điểm trong khoảng từ -10 đến 10 trên 2 đồ thị cạnh nhau.

# %% [markdown]
# **Cách 1**

# %% [markdown]
# **Cách 2**

# %% [markdown]
# **Cách 3**

# %% [markdown]
# ### 2. Đồ thị phân phối (Histogram/Distribution)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris= sns.load_dataset('iris') #tập dữ liệu cơ bản khi bắt đầu học về machine learning tương ứng vs 4 features
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# #### **Thực hành**: Vẽ đồ thị phân phối độ dài cánh hoa tương ứng cột `sepal_length`.
#
# #### **Sử dụng Matplotlib**:

# %%
#tận dụng hàm, truyền cột mà muốn vẽ phân bố lên
#có 2 cách biểu diễn gọi 1 cột or series trong 1 DF, tên cột mà được viết liền thì chọn 1 trong hai cách, nếu 
#tên viết cách (có dấu cách ) thì thường là ['']
plt.hist(iris['sepal_length'], bins=10) # bins là các cột tính bằng cách lấy min, max của cột dữ liệu đó sau lấy trung bình.
#xlabel, y label, title homework
plt.show()

# %%
#check thông số
iris['sepal_length'].describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal_length, dtype: float64

# %% [markdown]
# #### **Sử dụng Seaborn**:

# %%
sns.histplot(iris['sepal_length']) # mặc đinh là 10bins, nếu k truyền bins
plt.show()

# %%
#seaborn đẹp hơn matplotlib một chút, truyền 1 cột 1 series.
# nếu muốn truyền 1 data.
sns.histplot(iris, x='sepal_length')
plt.show()

# %% [markdown]
# Ngoài ra, ta có thể sử dụng hàm `distplot()` như ví dụ dưới đây:

# %% [markdown]
# ### 3. Đồ thị phân tán (Scatter plot)
#
# #### **Thực hành**: Vẽ đồ thị phân tán độ dài cánh hoa và đài hoa tương ứng cột `sepal_length` và `petal_length`.
#
# #### **Sử dụng Matplotlib**:

# %%
# biểu thị độ tương quan của 2 biến or cụm features, cần cóm ít nhất 2 giá trị.

# %%
plt.scatter(iris.petal_length, iris.petal_width, marker='*',label='petal') # 1mqh tuyến tính, scatter là cái chấm, để biết chấm nào miêu tả
plt.scatter(iris.sepal_length, iris.sepal_width, label='sepal')
plt.legend()
plt.show
#https://matplotlib.org/stable/api/markers_api.html
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### **Sử dụng Seaborn**:

# %%
sns.scatterplot(data=iris, x= 'petal_length', y='petal_width', label='petal')
sns.scatterplot(data=iris, x= 'sepal_length', y='sepal_width', label='sepal')
plt.legend()

# %% [markdown]
# #### **Thực hành**: Vẽ đồ thị phân tán độ dài và độ rộng đài hoa tương ứng cột `petal_length`.
#
# #### **Sử dụng Matplotlib**:

# %%
#k quan tâm đài hoa, cánh hoa, với các đặc trưng này thì 
# vẽ đồ thị biểu diễn được 1 đặc trưng ba giống hoa nằm trong cụm nào?
# mqh độ dài độ rộng cánh hoa, giống hoa nào nằm trong phân bố điểm nào??

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.scatter(iris[iris.species=='setosa'].petal_length, iris[iris.species=='setosa'].petal_width, marker='*',label='setosa')
plt.scatter(iris[iris.species=='versicolor'].petal_length, iris[iris.species=='versicolor'].petal_width,label='versicolor')
plt.scatter(iris[iris.species=='virginica'].petal_length, iris[iris.species=='virginica'].petal_width,label='virginica')
#c1tạo ra 3 scatterplot tương ứng với 3 loại hoa setosa', 'versicolor', 'virginica
plt.legend()

# %% [markdown]
# #### **Sử dụng Seaborn**:

# %%
#nếu dùng matplotlib thì phải làm thủ công 3 lần
# ở seaborn thì có cách nhanh hơn
sns.scatterplot(data=iris, x='petal_length', y='petal_width', hue='species', palette=['red', 'blue', 'brown']) #hue giúp chúng ta phân biệt màu sắc giữa các điểm dữ liệu
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 4. Đồ thị hộp (Box plot)
#
# #### **Thực hành**: Vẽ biểu đồ hộp độ dài đài hoa tương ứng cột `petal_length`.

# %%
#trực quan hóa cái hàm describe thành hình ảnh.
iris['petal_length'].describe() # tưởng tượng ra phân bố của hàm dữ liệu mình muốn đánh giá.
#viết báo cáo có nhiều hơn 10 cột dữ liệu thì k thể gửi các con số này được, 
# hỗ trợ hàm để vẽ đồ thị hộp, để đưa ra đánh giá trên kiểu dữ liệu này
# Out:
# count    150.000000
# mean       3.758000
# std        1.765298
# min        1.000000
# 25%        1.600000
# 50%        4.350000
# 75%        5.100000
# max        6.900000
# Name: petal_length, dtype: float64

# %%
plt.boxplot(iris['petal_length'], vert=False) #vert để đồ thị nằm ngang, none thì là đứng
plt.show
#đồ thị sẽ dóng ra được các thông số ở trên.
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(data=iris, x='petal_length', width=0.2) 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#nếu chuyển theo chiều dọc thì chuyển thành y
sns.boxplot(data=iris, y='petal_length', width=0.2) 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### **Thực hành**: Vẽ biểu đồ hộp các cột dữ liệu trong `iris`.
# #### **Sử dụng Matplotlib**:

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
plt.boxplot([iris['sepal_length'],iris['sepal_width'], iris['petal_length'],  iris['petal_width']], vert=False) #vert để đồ thị nằm ngang, none thì là đứng
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### **Sử dụng Seaborn**:

# %%
sns.boxplot(data=iris, width=0.5) #chỉ ứng dụng cho dữ liệu dạng số, nếu cột nào ở dạng str thì sẽ k đưa vào đây
plt.show()

# %% [markdown]
# Ngoài ra, chúng ta có 1 vài hàm biến thể nhằm trực quan hoá mô tả phân bố dữ liệu, tham khảo 1 số hàm dưới đây:

# %%
sns.boxenplot(data=iris)
plt.show()

# %%
sns.violinplot(data=iris)
plt.show()

# %% [markdown]
# ### 5. Biểu đồ tròn (Pie chart)

# %%
tips=sns.load_dataset('tips')
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# #### **Thực hành**: Vẽ biểu đồ tròn thể hiện giới tính nam và nữ chiếm bao nhiêu phần trăm trong tổng hoá đơn.

# %%
# 2 giới tính. Nam thì tổng bills trả là bao nhiêu?, Nữ thì tổng bill trả bao nhiêu
# sau đó vẽ ra 1 pie chart thể hiện phần % phân bố.
tips.groupby('sex').total_bill.sum()
# Out:
# sex
# Male      3256.82
# Female    1570.95
# Name: total_bill, dtype: float64

# %%
sex.index
# Out:
# CategoricalIndex(['Male', 'Female'], categories=['Male', 'Female'], ordered=False, name='sex', dtype='category')

# %% [markdown]
# #### **Sử dụng Matplotlib**:

# %%
sex= tips.groupby('sex').total_bill.sum()
plt.pie(sex, labels=sex.index, autopct='%.2f%%') #labels có thể gọi index ra thì sẽ k bị nhầm lẫn, autopct, sau số thập phân là bao nhiêu số
plt.show()

# %% [markdown]
# #### **Sử dụng Seaborn**:
# Seaborn thì không hỗ trợ trực tiếp **pie chart**, ta có thể sử dụng **bar plot chart** thay thế.

# %%
sex1=pd.DataFrame(sex).reset_index()
sex1
# Out:
#       sex  total_bill
# 0    Male     3256.82
# 1  Female     1570.95

# %%
sns.barplot(data=sex1, x='sex', y='total_bill')
plt.show()

# %% [markdown]
# Ta cũng có thể sử dụng barplot với thư viện Matplotlib và Pandas như dưới đây:

# %%
plt.bar(data=sex1, x='sex', height='total_bill', color= ['blue', 'orange'])
plt.show()

# %%
sex1.plot(kind='bar')#=sex1.plot.bar()
plt.show()

# %%
#nếu muốn lật ngược barh
sex1.plot(kind='barh')#=sex1.plot.bar()
plt.show()

# %% [markdown]
# **Bonus**: Ta có thể sử dụng `countplot()` để đếm số lượng, ví dụ:

# %%
sns.countplot(data=tips, x='sex')
plt.show()

# %% [markdown]
# #### **Thực hành**: Vẽ biểu đồ tròn thể hiện giới tính nam và nữ chiếm bao nhiêu phần trăm trong tổng hoá đơn phía bên trái và biểu đồ tròn thể hiện tổng hoá đơn tiêu thụ theo ngày phía bên phải.

# %%
#bài tập về nhà: total_bills, biểu diễn nó, bên trái tổng cho KH, bên phải là tổng theo ngày trong tuần.
#tạo barchart có miếng lệch ra khỏi vòng tròn chung
#cách trực quan hóa hai đồ thị cạnh nhau

# %% [markdown]
# #### **Bài tập**: Vẽ biểu đồ tròn thể hiện giới phần trăm tổng hoá đơn tiêu thụ của nam theo ngày.

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#giới tính nam condition= tips['sex']=='Male', nếu nhiều đk thì dùng dấu ngoặc tròn ()
#tổng tiêu thụ bao nhiêu từng ngày
#vẽ kq lên bar chart
male= tips[tips['sex']=='Male'].groupby('day').total_bill.sum()
plt.pie(male, labels=male.index, autopct='%.2f%%', explode=[0,0.3,0,0]) 
# lUU Ý truyen 0 thì nó nằm ở đâu vẫn nằm ấy, nếu truyền số dương 
#thì theo thứ tự index đầu đến cuối, explode=0.1 thì bánh dịch ra chút xíu
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 6. Một số biểu đồ tương quan phức hợp (Giới thiệu)

# %% [markdown]
# Trong bài học tiếp theo, chúng ta sẽ cùng nhau tìm hiểu về Học máy, các bài toán trong Học máy và tiếp cận đến loại bài toán đầu tiên trong Học máy, đó là Học có giám sát.

# %%
#FacetGrid với các đk khác nhau trực quan dữ liệu
#muốn plot tương quan total bill và tips, với đk Nam, Nữ, hút thuốc hay k....thì hoàn toàn có thể tận dụng FacetGrid để làm
#sns.scatterplot
g= sns.FacetGrid(data=tips, col='sex')
g.map(sns.scatterplot, 'total_bill', 'tip')
plt.show()

# %%
g= sns.FacetGrid(data=tips, col='sex', row='smoker')
g.map(sns.scatterplot, 'total_bill', 'tip')
plt.show()

# %%
g= sns.FacetGrid(data=tips, col='sex', row='smoker', hue='time') #tối đa là 2-3 điều kiện thôi.
g.map(sns.scatterplot, 'total_bill', 'tip')
plt.show()

# %%
#không biết đặc trưng nào là quan trọng thì dùng pairplot, show 2 cặp 1 để xem hành vi phân bố ntn
sns.pairplot(iris, hue='species', height=1.5)
plt.show()
#ma trận vuông đối xứng
# mình hoàn toàn có thể đưa ra 1 hue, đổi màu theo cột mình mong muốn.
